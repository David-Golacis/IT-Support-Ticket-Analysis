# %% [markdown]
# # IT Support Dashboard - Supporting Notebook
#
# This notebook contains supporting documentation to the full report. Here, we provide quality checks for the full dataset, confirm whether the English-only sample is representitive of the full population available, and conduct text analytics.

# %%
# Importing essential packages
import sys
from pathlib import Path
import pandas as pd

# Add parent directory (project root) to sys.path
project_root = Path(r"C:\Users\David\Desktop\Python_Files\IT-Support-Ticket-Analysis")
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

from config import Config

Config.ensure_directories()

# Reading the initial dataset as a DataFrame: df
df = pd.read_csv(
    Config.RAW_DATA_PATH,
    encoding="utf-8",
    engine="python",
    on_bad_lines="skip",
    na_values=["", " ", "NA", "N/A", "na", "n/a", "NULL", None],
)

df  # Display the DataFrame to verify successful import
# Out:
# [Config] Verified project directory structure under C:\Users\David\Desktop\Python_Files\IT-Support-Ticket-Analysis
#                                                  subject  \
# 0                        Wesentlicher Sicherheitsvorfall
# 1                                     Account Disruption
# 2      Query About Smart Home System Integration Feat...
# 3                      Inquiry Regarding Invoice Details
# 4      Question About Marketing Agency Software Compa...
# ...                                                  ...
# 28582       Performance Problem with Data Analytics Tool
# 28583          Datensperrung in der Kundschaftsbetreuung
# 28584      Problem mit der Videokonferenz-Software heute
# 28585  Update Request for SaaS Platform Integration F...
# 28586          Inquiry About Project Management Features
#
#                                                     body  \
# 0      Sehr geehrtes Support-Team,\n\nich möchte eine...
# 1      Dear Customer Support Team,\n\nI am writing to...
# 2      Dear Customer Support Team,\n\nI hope this mes...
# 3      Dear Customer Support Team,\n\nI hope this mes...
# 4      Dear Support Team,\n\nI hope this message reac...
# ...                                                  ...
# 28582  The data analytics tool experiences sluggish p...
# 28583  Es gab einen Datensperrungsunfall, bei dem ung...
# 28584  Wichtigere Sitzungen wurden unterbrochen durch...
# 28585  Requesting an update on the integration featur...
# 28586  Looking for detailed information on the projec...
#
#                                                   answer      type  \
# 0      Vielen Dank für die Meldung des kritischen Sic...  Incident
# 1      Thank you for reaching out, <name>. We are awa...  Incident
# 2      Thank you for your inquiry. Our products suppo...   Request
# 3      We appreciate you reaching out with your billi...   Request
# 4      Thank you for your inquiry. Our product suppor...   Problem
# ...                                                  ...       ...
# 28582  We are addressing the performance issue with t...  Incident
# 28583  Ich kann Ihnen bei dem Datensperrungsunfall he...  Incident
# 28584  Sehr geehrte/r [Name], leider wurde das Proble...  Incident
# 28585  Received your request for updates on the integ...    Change
# 28586  Dear [Name], thank you for your email regardin...   Request
#
#                        queue priority language  version        tag_1  \
# 0          Technical Support     high       de       51     Security
# 1          Technical Support     high       en       51      Account
# 2      Returns and Exchanges   medium       en       51      Product
# 3       Billing and Payments      low       en       51      Billing
# 4        Sales and Pre-Sales   medium       en       51      Product
# ...                      ...      ...      ...      ...          ...
# 28582      Technical Support     high       en      400  Performance
# 28583        Product Support     high       de      400     Security
# 28584        Human Resources      low       de      400          Bug
# 28585             IT Support     high       en      400      Feature
# 28586      Technical Support      low       en      400      Feature
#
#                tag_2         tag_3          tag_4         tag_5 tag_6 tag_7  \
# 0             Outage    Disruption    Data Breach           NaN   NaN   NaN
# 1         Disruption        Outage             IT  Tech Support   NaN   NaN
# 2            Feature  Tech Support            NaN           NaN   NaN   NaN
# 3            Payment       Account  Documentation      Feedback   NaN   NaN
# 4            Feature      Feedback   Tech Support           NaN   NaN   NaN
# ...              ...           ...            ...           ...   ...   ...
# 28582             IT  Tech Support            NaN           NaN   NaN   NaN
# 28583             IT  Tech Support            Bug           NaN   NaN   NaN
# 28584    Performance       Network             IT  Tech Support   NaN   NaN
# 28585             IT  Tech Support            NaN           NaN   NaN   NaN
# 28586  Documentation      Feedback             IT           NaN   NaN   NaN
#
#       tag_8
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ...     ...
# 28582   NaN
# 28583   NaN
# 28584   NaN
# 28585   NaN
# 28586   NaN
#
# [28587 rows x 16 columns]

# %% [markdown]
# ### Quality checking the dataset
#
# We wanted to see how clean and complete this dataset was. We were looking at the shape of the table, missing values, if dimensions were in appropriate datatypes, how much memory they used, and if any further information could be gathered from descriptive statistics.

# %%
# Information about the dataset
print("What is the shape of my table?")
print(df.shape)
print("\nAre there any missing values in each dimension?")
print(df.isna().sum().sort_values())
print("\nWhat is the datatype of each column?")
print(df.dtypes)
print("\nHow many bytes does each column use?")
print(df.memory_usage())
# Out:
# What is the shape of my table?
# (28587, 16)
#
# Are there any missing values in each dimension?
# body            0
# type            0
# queue           0
# priority        0
# language        0
# version         0
# tag_1           0
# answer          7
# tag_2          13
# tag_3         136
# tag_4        3058
# subject      3838
# tag_5       14042
# tag_6       22713
# tag_7       26547
# tag_8       28022
# dtype: int64
#
# What is the datatype of each column?
# subject     object
# body        object
# answer      object
# type        object
# queue       object
# priority    object
# language    object
# version      int64
# tag_1       object
# tag_2       object
# tag_3       object
# tag_4       object
# tag_5       object
# tag_6       object
# tag_7       object
# tag_8       object
# dtype: object
#
# How many bytes does each column use?
# Index          132
# subject     228696
# body        228696
# answer      228696
# type        228696
# queue       228696
# priority    228696
# language    228696
# version     228696
# tag_1       228696
# tag_2       228696
# tag_3       228696
# tag_4       228696
# tag_5       228696
# tag_6       228696
# tag_7       228696
# tag_8       228696
# dtype: int64

# %%
# Identify rows with null answers; subjects and tags were ignored as they were less critical to this analysis
null_answers = df[df["answer"].isna() == True]
print("\nTable containing rows with null answers:")
display(null_answers)

# Dropping null answers and resetting index
df = df.dropna(subset=["answer"])
df.reset_index(drop=True, inplace=True)
print("\nDataframe after dropping null answers and resetting index:")
display(df)

# Converting data types to save on memory usage
# Lists of data types by column
categories = [
    "type",
    "queue",
    "priority",
    "language",
    "version",
    "tag_1",
    "tag_2",
    "tag_3",
    "tag_4",
    "tag_5",
    "tag_6",
    "tag_7",
    "tag_8",
]
strings = ["subject", "body", "answer"]

# List comprehension loop
for types in df:
    # Categories
    for category in categories:
        if types == category:
            df[types] = df[types].astype("category")

    # Integers
    for string in strings:
        if types == string:
            df[types] = df[types].astype("string")

# Standardizing text in 'priority' and 'language' columns to title case
df["priority"] = df["priority"].str.title()
df["language"] = df["language"].str.title()
# Out:
# Table containing rows with null answers:
#                                                  subject  \
# 4956      Support Inquiry Regarding SendGrid Integration
# 5381            Support Request for SendGrid Integration
# 12163  Recent Decline in Engagement Metrics Noted Online
# 13378  Recent Decrease in Engagement Metrics Noted On...
# 13651                                                NaN
# 16596  Sicher, Benutzer melden zeitweise Verbindungsp...
# 26522       Reduction in Engagement Metrics Noted Online
#
#                                                     body answer      type  \
# 4956   Dear Customer Service, I would like to inquire...    NaN   Request
# 5381   Dear Customer Service, I would like to inquire...    NaN   Request
# 12163  We have observed a decrease in engagement metr...    NaN   Problem
# 13378  There has been a decline in engagement metrics...    NaN   Problem
# 13651  We are sorry to hear that you are experiencing...    NaN   Problem
# 16596  rufen Sie uns an <tel_num>, um über weitere Lö...    NaN  Incident
# 26522  Observation of a decline in engagement metrics...    NaN   Problem
#
#                       queue priority language  version     tag_1        tag_2  \
# 4956   Billing and Payments     high       de       52   Billing      Payment
# 5381   Billing and Payments     high       de       52   Billing      Payment
# 12163       Product Support   medium       en      400  Feedback  Performance
# 13378       Product Support   medium       en      400  Feedback  Performance
# 13651     Technical Support     high       en      400       Bug  Performance
# 16596      Customer Service      low       de      400   Network  Performance
# 26522       Product Support   medium       de      400  Feedback  Performance
#
#             tag_3          tag_4         tag_5      tag_6        tag_7  \
# 4956     Platform        Pricing      Discount  Promotion  Integration
# 5381      Support    Integration       Pricing  Promotion          NaN
# 12163     Feature            NaN           NaN        NaN          NaN
# 13378     Feature            NaN           NaN        NaN          NaN
# 13651     Feature  Documentation  Tech Support        NaN          NaN
# 16596  Disruption             IT  Tech Support        NaN          NaN
# 26522     Feature  Documentation           NaN        NaN          NaN
#
#          tag_8
# 4956   Support
# 5381       NaN
# 12163      NaN
# 13378      NaN
# 13651      NaN
# 16596      NaN
# 26522      NaN
# Dataframe after dropping null answers and resetting index:
#                                                  subject  \
# 0                        Wesentlicher Sicherheitsvorfall
# 1                                     Account Disruption
# 2      Query About Smart Home System Integration Feat...
# 3                      Inquiry Regarding Invoice Details
# 4      Question About Marketing Agency Software Compa...
# ...                                                  ...
# 28575       Performance Problem with Data Analytics Tool
# 28576          Datensperrung in der Kundschaftsbetreuung
# 28577      Problem mit der Videokonferenz-Software heute
# 28578  Update Request for SaaS Platform Integration F...
# 28579          Inquiry About Project Management Features
#
#                                                     body  \
# 0      Sehr geehrtes Support-Team,\n\nich möchte eine...
# 1      Dear Customer Support Team,\n\nI am writing to...
# 2      Dear Customer Support Team,\n\nI hope this mes...
# 3      Dear Customer Support Team,\n\nI hope this mes...
# 4      Dear Support Team,\n\nI hope this message reac...
# ...                                                  ...
# 28575  The data analytics tool experiences sluggish p...
# 28576  Es gab einen Datensperrungsunfall, bei dem ung...
# 28577  Wichtigere Sitzungen wurden unterbrochen durch...
# 28578  Requesting an update on the integration featur...
# 28579  Looking for detailed information on the projec...
#
#                                                   answer      type  \
# 0      Vielen Dank für die Meldung des kritischen Sic...  Incident
# 1      Thank you for reaching out, <name>. We are awa...  Incident
# 2      Thank you for your inquiry. Our products suppo...   Request
# 3      We appreciate you reaching out with your billi...   Request
# 4      Thank you for your inquiry. Our product suppor...   Problem
# ...                                                  ...       ...
# 28575  We are addressing the performance issue with t...  Incident
# 28576  Ich kann Ihnen bei dem Datensperrungsunfall he...  Incident
# 28577  Sehr geehrte/r [Name], leider wurde das Proble...  Incident
# 28578  Received your request for updates on the integ...    Change
# 28579  Dear [Name], thank you for your email regardin...   Request
#
#                        queue priority language  version        tag_1  \
# 0          Technical Support     high       de       51     Security
# 1          Technical Support     high       en       51      Account
# 2      Returns and Exchanges   medium       en       51      Product
# 3       Billing and Payments      low       en       51      Billing
# 4        Sales and Pre-Sales   medium       en       51      Product
# ...                      ...      ...      ...      ...          ...
# 28575      Technical Support     high       en      400  Performance
# 28576        Product Support     high       de      400     Security
# 28577        Human Resources      low       de      400          Bug
# 28578             IT Support     high       en      400      Feature
# 28579      Technical Support      low       en      400      Feature
#
#                tag_2         tag_3          tag_4         tag_5 tag_6 tag_7  \
# 0             Outage    Disruption    Data Breach           NaN   NaN   NaN
# 1         Disruption        Outage             IT  Tech Support   NaN   NaN
# 2            Feature  Tech Support            NaN           NaN   NaN   NaN
# 3            Payment       Account  Documentation      Feedback   NaN   NaN
# 4            Feature      Feedback   Tech Support           NaN   NaN   NaN
# ...              ...           ...            ...           ...   ...   ...
# 28575             IT  Tech Support            NaN           NaN   NaN   NaN
# 28576             IT  Tech Support            Bug           NaN   NaN   NaN
# 28577    Performance       Network             IT  Tech Support   NaN   NaN
# 28578             IT  Tech Support            NaN           NaN   NaN   NaN
# 28579  Documentation      Feedback             IT           NaN   NaN   NaN
#
#       tag_8
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ...     ...
# 28575   NaN
# 28576   NaN
# 28577   NaN
# 28578   NaN
# 28579   NaN
#
# [28580 rows x 16 columns]
# C:\Users\David\AppData\Local\Temp\ipykernel_17636\3534126513.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[types] = df[types].astype("string")
# C:\Users\David\AppData\Local\Temp\ipykernel_17636\3534126513.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[types] = df[types].astype("string")
# C:\Users\David\AppData\Local\Temp\ipykernel_17636\3534126513.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[types] = df[types].astype("string")
# C:\Users\David\AppData\Local\Temp\ipykernel_17636\3534126513.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[types] = df[types].astype("category")
# C:\Users\David\AppData\Local\Temp\ipykernel_17636\3534126513.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[types] = df[types].astype("category")
# C:\Users\David\AppData\Local\Temp\ipykernel_17636\3534126513.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[types] = df[types].astype("category")
# C:\Users\David\AppData\Local\Temp\ipykernel_17636\3534126513.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[types] = df[types].astype("category")
# C:\Users\David\AppData\Local\Temp\ipykernel_17636\3534126513.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[types] = df[types].astype("category")
# C:\Users\David\AppData\Local\Temp\ipykernel_17636\3534126513.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[types] = df[types].astype("category")
# C:\Users\David\AppData\Local\Temp\ipykernel_17636\3534126513.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[types] = df[types].astype("category")
# C:\Users\David\AppData\Local\Temp\ipykernel_17636\3534126513.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[types] = df[types].astype("category")
# C:\Users\David\AppData\Local\Temp\ipykernel_17636\3534126513.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[types] = df[types].astype("category")
# C:\Users\David\AppData\Local\Temp\ipykernel_17636\3534126513.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[types] = df[types].astype("category")
# C:\Users\David\AppData\Local\Temp\ipykernel_17636\3534126513.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[types] = df[types].astype("category")
# C:\Users\David\AppData\Local\Temp\ipykernel_17636\3534126513.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[types] = df[types].astype("category")
# C:\Users\David\AppData\Local\Temp\ipykernel_17636\3534126513.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[types] = df[types].astype("category")
# C:\Users\David\AppData\Local\Temp\ipykernel_17636\3534126513.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['priority'] = df['priority'].str.title()
# C:\Users\David\AppData\Local\Temp\ipykernel_17636\3534126513.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['language'] = df['language'].str.title()

# %%
print("What is the shape of my table?")
print(df.shape)
print("\nAre there any missing values in each dimension?")
print(df.isna().sum().sort_values())
print("\nWhat is the datatype of each column?")
print(df.dtypes)
print("\nHow many bytes does each column use?")
print(df.memory_usage())
# Out:
# What is the shape of my table?
# (28580, 16)
#
# Are there any missing values in each dimension?
# body            0
# answer          0
# type            0
# queue           0
# priority        0
# language        0
# version         0
# tag_1           0
# tag_2          13
# tag_3         136
# tag_4        3056
# subject      3837
# tag_5       14039
# tag_6       22708
# tag_7       26541
# tag_8       28016
# dtype: int64
#
# What is the datatype of each column?
# subject     string[python]
# body        string[python]
# answer      string[python]
# type              category
# queue             category
# priority            object
# language            object
# version           category
# tag_1             category
# tag_2             category
# tag_3             category
# tag_4             category
# tag_5             category
# tag_6             category
# tag_7             category
# tag_8             category
# dtype: object
#
# How many bytes does each column use?
# Index          132
# subject     228640
# body        228640
# answer      228640
# type         28784
# queue        28960
# priority    228640
# language    228640
# version      28712
# tag_1        33676
# tag_2        67504
# tag_3        68592
# tag_4        78144
# tag_5        78528
# tag_6        78312
# tag_7        77128
# tag_8        67248
# dtype: int64

# %% [markdown]
# Continuing on with the quality checks, we wanted to confirm how many unique values there were under each dimension. This would save time later on by avoiding manual processing of the dataset to identify these findings.

# %%
# Loop to extract all unique values from each column in df
for column in df.columns:
    unique_values = df[column].sort_values(ascending=True).unique()
    length = len(unique_values)
    print(f"There were {length} unique values in {column}:\n{unique_values}")
    print("")
# Out:
# There were 24744 unique values in subject:
# <StringArray>
# [                                                                                                                                                                                              ' Assistance Request',
#                                                                                                                                          ' Bitte um Ausführliche Informationen zur Datenaufbereitungsdienstleistung',
#                                                                                                                                                                    ' Datenschutzverletzung in Krankenhaus-Systemen ',
#                                                                                                                                                                                 ' Reported Problem with Data Access',
#                                                                                                                                                                       ' Urgent Investigation Needed for Data Breach',
#                                                                                                                                                           ' Urgent Support Required for Project Management Platform',
#                                                                                                                          ' encountered issues with data analytics tools impacting investment optimization processes',
#                                                                                                                                                                             ' sluggish performance of SaaS platform',
#                                                                                                                                                                     ' sluggish performance of the Project Dashboard',
#                                                                                                                                                                             ' sluggish performance on SaaS platform',
#  ...
#                                                                                                                            'Überprüfung und Aktualisierung des Wartungsschedules und Verbesserung der Kommunikation',
#  'Überprüfung und Aktualisierung von Kompatibilitätsstellungen für verschiedene Software und Hardware, sowie Verbesserung der Integration innerhalb des Projektmanagement SaaS-Platforms zur Leistungsverbesserung.',
#                                                                                                                                  'Überprüfung von Ausfällen in Finanzsoftware-Systemen wie Xero und Sage Accounting',
#                                                                                                                                                                      'Überprüfung von Digitalen Marketingstrategien',
#                                                                                                                                                                     'Überprüfung von Investitionszurückgangsanalyse',
#                                                                                                                                                         'Überprüfung von Rechnungsdisparitäten bei SaaS-Abonnements',
#                                                                                                                                                                      'Übersicht der Sicherheitsmaßnahmen im Betrieb',
#                                                                                                                                                                                  'Übersicht der digitalen Kampagnen',
#                                                                                                                                                            'Überwachung medizinischer Daten in Krankenhaus-Systemen',
#                                                                                                                                                                                                                 <NA>]
# Length: 24744, dtype: string
#
# There were 28580 unique values in body:
# <StringArray>
# [                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ' Assistance Requested',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ' Assistance Required',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ' Assistance needed',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ' Probleme mit der HubSpot CRM-Integration auf mehreren Geräten. Neueste Updates für PowerPoint 2021 unter macOS Monterey könnten die Ursache sein. Ich habe versucht, das Problem durch Neinstallation zu beheben und Verbindungen zu überprüfen, aber es behält seinen Ursprung. Ich brauche Hilfe, um das Problem zu lösen.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                           ' Schwierigkeiten bei der Datenzugriffsermächtigung für die Sicherung der Medikationsdatenverwaltung aufgrund von Server-Konfigurationsfehlern und Softwarekompabilitätsproblemen. Versucht, Netzwerkgeräte zu resetten und Sicherheitssoftware neu zu installieren, ohne dass sich das Problem löste. Dringend Hilfe benötigt, um das Problem zu lösen und die Integrität unserer Medizindaten zu gewährleisten.',
#                                                                                                                                                                                                                                                         ' geehrte Kundenservice, ich kontaktiere Sie, um zu erfragen, welche Datenanalysefähigkeiten Ihrer Optimierungsdienste für Investitionen bieten. Könnten Sie Einblicke in die Eingesetzten Werkzeuge und Techniken geben, die Investitionsdaten analysieren? Ich freue mich auf Informationen, die uns helfen, unsere Investitionsportfolios zu optimieren und die Renditen zu verbessern. Darüber hinaus möchte ich erfahren, welche Dienste für realzeitbedingte Datenanalyse und Berichterstattung verfügbar sind. Danke für Ihre Unterstützung. Ich freue mich darauf, bald von Ihnen zu hören.',
#                                                                                                                                                                                                                                                                                                                                                                                                                         ' geehrte Kundenservice, könnten Sie mir zusätzliche Informationen zu digitalen Strategien zur Förderung des Markenwachstums geben? Ich freue mich darauf, konkrete Maßnahmen zu erfahren, die wir nutzen können, um die Markenbewusstheit und das Engagement zu steigern. Könnten Sie mir empfehlenswerte Werkzeuge und Plattformen nennen? Ich bedanke mich im Voraus für Ihre Unterstützung und freue mich auf eine Rückmeldung.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ' needing support. there was an incident involving unauthorized access to medical data. system updates were implemented and user training provided, but access issues still persist.',
#                                                                                                                                                                                                                                                                                                                                 '15. Oktober zeigten sich Störungen bei Design- und Automatisierungsprozessen, wobei Figma und Zapier unzugänglich waren. Obwohl die Geräte neu gestartet und die Internetverbindung überprüft wurde, sowie versucht wurde, beeinträchtigende Anwendungen neu zu installieren, bestehen die Probleme weiterhin. Die neuesten Softwareupdates werden als Folge von Misskonfigurationen auf Apple MacBook Air zurückgeführt. Wir benötigen Ihre Unterstützung, um das Problem zu beheben und die Prozesse wiederherzustellen.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   'A billing discrepancy has arisen on Adobe Effects GitHub following the latest system update. Despite attempts to reconcile the account and contacting customer service, a resolution has not been reached. Assistance is required to address this issue.',
#  ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'unusual decrease in agency metrics',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 'unzustimmenden Zugriffsbemühen auf das Krankenhaus-IT-System festgestellt.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    'update the data analysis infrastructure, optimize the plant management for various products. The update will extend the capability to provide timely accurate insights to make better equipment decisions. The update is expected to be completed soon.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     'went through a data breach because of inadequate encryption methods and outdated systems. Tried to upgrade security software, but the issues continue.',
#                                                                                                                                                                                                                                                                                                                                                                               'went through unforeseen downtime with various products, such as Twitch Studio Beta and MATLAB. outage possibly due to recent software updates or network troubles. so far, restarted involved applications and verified server connections, but to no avail. team is diligently working to resolve the issue and prevent future occurrences. thank you for your patience and understanding. should you have any questions or concerns, please do not hesitate to contact us.',
#  'wir erleben momentan signifikante Dienstunterbrechungen bei mehreren Integrationsdiensten. es wird vermutet, dass die neuesten Systemupdates die Serverlast erhöht haben. unser team hat versucht, die betroffenen Dienste neu zu starten und die updates rückgängig zu machen, jedoch konnte das problem leider nicht sofort gelöst werden. wir arbeiten intensiv daran, die Ursache zu identifizieren und eine Lösung zu implementieren, um dies so schnell wie möglich zu beheben. bitte entschuldigen Sie die Unannehmlichkeiten und die Unterbrechung, die durch die Dienstunterbrechung verursacht werden mag. wir bedanken uns für Ihr Verständnis und Ihre Geduld. falls Sie weitere Fragen oder Bedenken haben, melden Sie uns bitte. wir informieren Sie gerne über den aktuellen Stand und schätzen Ihre Bemerkungen zu diesem Thema schätzen.',
#                                                                                                                                                                                                                                                                                                                                            'wirten Sie, um Integration von Zapier mit bestehenden Datenanalysetools zu besprechen. Gibt es detaillierte Informationen zum Integrationsprozess? Sie möchten mehr über die Möglichkeiten erfahren, wie Zapier Datenanalyse und Aufgaben automatisieren kann. Insbesondere interessiert Sie die Art der Datenanalysetools, die mit Zapier kompatibel sind und welche Anforderungen für die Integration bestehen. Ich freue mich auf Ihre Rückmeldung in Kürze und danke Ihnen für Ihre Zeit und Unterstützung.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             'wishes to enhance data analysis tools for better optimization of decision-making processes for financial strategies to achieve better results.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     'Änderungen in den Datenanalyseberichten wurden bemerkt. Obwohl die Berichte neu ausgeführt wurden, bestehen weiterhin Probleme mit den Dateneingaben. Neueste Software-Updates könnten der Grund sein.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             'Überarbeitung der Datenanalyse, um Investitionen zu verbessern']
# Length: 28580, dtype: string
#
# There were 28580 unique values in answer:
# <StringArray>
# [                                                                                                                                                                                                                                                                                                                                                                                       ' Nehmen wir diesen Fall ernst. Bitte bereiten Sie zusätzliche Details des Vorfalls vor und rufen Sie uns unter <tel_num> an. Wir werden die nächsten Schritte zur Sicherung der Systeme besprechen.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ' escalate the incident to the cybersecurity team for investigation and prompt resolution of the data breach',
#                                                                                                                                                                                                                                                                                                                                                                                       ' escalate the issue to the technical support team by contacting <tel_num>, collect relevant information, and provide a resolution to address the slowdowns in the investment data analytics platform.',
#                                                                                                                                                                                                                                                                                                                                                                                              ' escalate the issue to the technical support team by contacting <tel_num>, gather relevant details, and provide a solution to address the slowdowns in the investment data analytics platform.',
#                                                                                                                                                                                                                                                                                                   ''<name> acknowledges the email regarding the connectivity issues with the SaaS platform and appreciates the efforts of the team to resolve the issue. Would it be possible to schedule a call at your convenience to discuss and gather more information to assist with the resolution. '',
#                          ''<name>' values the suggestion to improve the project tracking user-friendly dashboard for our SaaS platform. We recognize the importance of a dashboard that offers a clear and concise overview of project progress and key metrics. Our development team is currently working on enhancing the platform's features, and your input is highly valuable to us. We would like to discuss your ideas and explore how they can benefit our users. Could you please provide more details on the specific features and functionalities you envision for the dashboard?',
#                                                                                                                                                                                                                   ''<name>' will take immediate action to address the reported security breach in hospital systems. Due to compromised medical data from outdated software, a thorough investigation will be conducted, software will be updated to ensure security, and affected patient data will be protected. All necessary support and information will be provided as required by law.',
#                                                                                                                                                         ''<name>' would be happy to help optimize investment strategies using IBM Cloud data analytics tools to improve returns. To better understand your current strategies, we would like to provide tailored guidance. Could you please share your current portfolio, investment goals, and the types of assets you are managing? Additionally, it would be helpful to know which specific data analytics tools you are currently using.',
#       ''Name' is pleased to provide guidance on securing medical data in Smartsheet within hospital systems. To ensure the security of sensitive medical information, it is recommended to implement robust access controls and encryption protocols. Smartsheet offers several security features, including two-factor authentication and data encryption both at rest and in transit. Regularly reviewing and updating user permissions and access levels is also suggested. For detailed information on security practices and protocols, 'Name' would be happy to schedule a discussion.',
#  ''Name', thank you for your inquiry regarding data analytics services to optimize investment strategies. Our services employ advanced algorithms and machine learning to analyze market trends, offering actionable insights that support informed investment decisions. We can help improve overall performance by identifying areas of inefficiency and providing tailored recommendations. Let's discuss how our services can best support your specific needs. I would be happy to schedule a call at your convenience, perhaps at <tel_num>, to explore these services in more detail.',
#  ...
#                                                                                                                                                                                                                                                                                                                                        'Überprüfung der bestehenden Sicherheitsvorkehrungen, Einführung verbesserter Schutzprotokolle, Schutz sensibler medizinischer Daten sicherstellen, die Sicherheit unserer Krankenhaus-IT-Systeme gewährleisten, bei Bedarf weitere Gespräche führen.',
#                                                                                                                                                                                                                                                                                                                                                             'Überprüfung der digitalen Kampagnen sowie Empfehlungen zur Optimierung der Zielgruppenansprache können die Leistung verbessern. Bitte erlauben Sie mir, einen geeigneten Zeitpunkt zu wählen, um weitere Details zu besprechen.',
#                                                                                                                                                                                                                                                                                                                                                                                                                        'Überprüfung der digitalen Marketingstrategie durchführen, Kontakt unter <tel_num> aufnehmen und mögliche Lösungsansätze für den Rückgang der Beteiligung besprechen.',
#                                                                                                                                                                                                                                                                                                                                                                                                                               'Überprüfung der digitalen Marketingstrategien, Kontaktaufnahme unter <tel_num> zur Besprechung möglicher Verbesserungen und Empfehlung der nächsten Schritte.',
#                                                                                                                                                                                                                                                                                                                                                                                               'Überprüfung des Problems unter <tel_num> durchführen, weitere Schritte und mögliche Lösungen zur Fehlerbehebung sowie zur Behebung von Integrationskonflikten bei digitalen Tools besprechen.',
#                                                                                                                                                                                                                                                                                                                                                                                                    'Überprüfung des Vorfallsberichts, Kontaktaufnahme unter <tel_num>, um weitere Unterstützung zu erhalten und die nächsten Schritte zur Lösung des Problems unter <acc_num> zu besprechen.',
#                                                                                                                                                                                                                                                                                                      'Überprüfung und Implementierung erweiterter Sicherheitsmaßnahmen, um medizinische Daten zu sichern und die Einhaltung branchenspezifischer Standards zu gewährleisten. Für weitere Details zu den nächsten Schritten bezüglich des <acc_num>-Kontos, kontaktieren Sie bitte <tel_num>.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                           'Überprüfung und Umsetzung der erweiterten Sicherheitsprotokolle, um die Kundendaten schnellstmöglich zu schützen.',
#                                                                                                                                                                                                                                                                                               'Überprüfung und Umsetzung verbesserter Verschlüsselungsmethoden sowie der Zugriffskontrollen in den beteiligten Systemen, um die Vertraulichkeit und Integrität sensibler Patientendaten sicherzustellen. Zudem soll der Fortschritt bei den Datensicherheitsprotokollen kommuniziert werden.',
#                                                                                                                                                                                                                                     'überprüfe E-Mail bezüglich niedriger Umwandlungsrate für digitale Marketingkampagnen. um den genauen Sachverhalt besser zu verstehen, bespreche gerne aktuelle Strategien und Ziele. Könnten Sie bitte mehr über bereits getroffene Anpassungen berichten? Anrufen Sie bitte unter <tel_num>, um eine Diskussion über mögliche Lösungen zu vereinbaren.']
# Length: 28580, dtype: string
#
# There were 4 unique values in type:
# ['Change', 'Incident', 'Problem', 'Request']
# Categories (4, object): ['Change', 'Incident', 'Problem', 'Request']
#
# There were 10 unique values in queue:
# ['Billing and Payments', 'Customer Service', 'General Inquiry', 'Human Resources', 'IT Support', 'Product Support', 'Returns and Exchanges', 'Sales and Pre-Sales', 'Service Outages and Maintenance', 'Technical Support']
# Categories (10, object): ['Billing and Payments', 'Customer Service', 'General Inquiry', 'Human Resources', ..., 'Returns and Exchanges', 'Sales and Pre-Sales', 'Service Outages and Maintenance', 'Technical Support']
#
# There were 3 unique values in priority:
# ['High' 'Low' 'Medium']
#
# There were 2 unique values in language:
# ['De' 'En']
#
# There were 3 unique values in version:
# [51, 52, 400]
# Categories (3, int64): [51, 52, 400]
#
# There were 116 unique values in tag_1:
# ['API', 'API Integration', 'Access', 'Accessibility', 'Account', ..., 'Urgency', 'User Interface', 'Video', 'Virus', 'Warranty']
# Length: 116
# Categories (116, object): ['API', 'API Integration', 'Access', 'Accessibility', ..., 'User Interface', 'Video', 'Virus', 'Warranty']
#
# There were 257 unique values in tag_2:
# ['AI', 'API', 'AWS', 'Access', 'Access Control', ..., 'Website', 'Website Issue', 'Windows', 'Workflow', NaN]
# Length: 257
# Categories (256, object): ['AI', 'API', 'AWS', 'Access', ..., 'Website', 'Website Issue', 'Windows', 'Workflow']
#
# There were 393 unique values in tag_3:
# ['API', 'API Integration', 'AWS', 'Access', 'Access Control', ..., 'Website Traffic', 'Windows', 'Workflow', 'macOS', NaN]
# Length: 393
# Categories (392, object): ['API', 'API Integration', 'AWS', 'Access', ..., 'Website Traffic', 'Windows', 'Workflow', 'macOS']
#
# There were 555 unique values in tag_4:
# ['AI', 'API', 'Access', 'Access Control', 'Access Management', ..., 'Warranty', 'Workflow', 'Workshop', 'Zapier', NaN]
# Length: 555
# Categories (554, object): ['AI', 'API', 'Access', 'Access Control', ..., 'Warranty', 'Workflow', 'Workshop', 'Zapier']
#
# There were 603 unique values in tag_5:
# ['API', 'AR', 'Abrechnungssystem', 'Access', 'Access Control', ..., 'Website Optimization', 'Website Traffic', 'Windows 10', 'Workflow', NaN]
# Length: 603
# Categories (602, object): ['API', 'AR', 'Abrechnungssystem', 'Access', ..., 'Website Optimization', 'Website Traffic', 'Windows 10', 'Workflow']
#
# There were 576 unique values in tag_6:
# ['API', 'Access', 'Access Control', 'Access Difficulty', 'Access Issue', ..., 'Webhook', 'Website', 'Workaround', 'Workflow', NaN]
# Length: 576
# Categories (575, object): ['API', 'Access', 'Access Control', 'Access Difficulty', ..., 'Webhook', 'Website', 'Workaround', 'Workflow']
#
# There were 428 unique values in tag_7:
# ['API', 'Access', 'Access Control', 'Access Management', 'Account', ..., 'Wi-Fi Security', 'Workaround', 'Workflow', 'Zapier', NaN]
# Length: 428
# Categories (427, object): ['API', 'Access', 'Access Control', 'Access Management', ..., 'Wi-Fi Security', 'Workaround', 'Workflow', 'Zapier']
#
# There were 225 unique values in tag_8:
# ['Access Control', 'Access Restriction', 'Account', 'Adjustment', 'Advertising', ..., 'Vulnerability', 'Website', 'Wi-Fi', 'Workflow', NaN]
# Length: 225
# Categories (224, object): ['Access Control', 'Access Restriction', 'Account', 'Adjustment', ..., 'Vulnerability', 'Website', 'Wi-Fi', 'Workflow']

# %%
# Importing os package for file operations
import os

# ----------------------------------------------------------
# 1. Define output file paths
# ----------------------------------------------------------
# Define file names
csv_path = Config.QC_CSV_DIR / "Tickets_Clean.csv"
parquet_path = Config.QC_CSV_DIR / "Tickets_Clean.parquet"
pickle_path = Config.QC_CSV_DIR / "Tickets_Clean.pkl"

# ----------------------------------------------------------
# Save in each format
# ----------------------------------------------------------
# CSV – portable
df.to_csv(csv_path, index=False, encoding="utf-8")

# Parquet – efficient
df.to_parquet(parquet_path, index=False, engine="pyarrow", compression="snappy")

# Pickle – fast, Python-dependent
df.to_pickle(pickle_path, protocol=5)

# ----------------------------------------------------------
# Print summary of saved files
# ----------------------------------------------------------
for path in [csv_path, parquet_path, pickle_path]:
    size_mb = os.path.getsize(path) / (1024 * 1024)
    print(f"{path.name:<25} | {size_mb:>6.2f} MB")

print("\nAll files saved successfully.")
# Out:
# Tickets_Clean.csv         |  24.79 MB
# Tickets_Clean.parquet     |  11.30 MB
# Tickets_Clean.pkl         |  23.47 MB
#
# All files saved successfully.
