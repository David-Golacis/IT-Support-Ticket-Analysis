# %% [markdown]
# # IT Support Dashboard - Supporting Notebook
#
# This notebook contains supporting documentation to the full report. Here, we provide quality checks for the full dataset, confirm whether the English-only sample is representitive of the full population available, and conduct text analytics.

# %%
# Importing essential packages
import sys
from pathlib import Path
import pandas as pd

# Add parent directory (project root) to sys.path
project_root = Path(r"C:\Users\David\Desktop\Python_Files\IT-Support-Ticket-Analysis")
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

from config import Config

Config.ensure_directories()

# Reading the initial dataset as a DataFrame: df
df = pd.read_csv(
    Config.RAW_DATA_PATH,
    encoding="utf-8",
    engine="python",
    on_bad_lines="skip",
)

df  # Display the DataFrame to verify successful import
# Out:
# [Config] Verified project directory structure under C:\Users\David\Desktop\Python_Files\IT-Support-Ticket-Analysis
#                                                  subject  \
# 0                        Wesentlicher Sicherheitsvorfall
# 1                                     Account Disruption
# 2      Query About Smart Home System Integration Feat...
# 3                      Inquiry Regarding Invoice Details
# 4      Question About Marketing Agency Software Compa...
# ...                                                  ...
# 28582       Performance Problem with Data Analytics Tool
# 28583          Datensperrung in der Kundschaftsbetreuung
# 28584      Problem mit der Videokonferenz-Software heute
# 28585  Update Request for SaaS Platform Integration F...
# 28586          Inquiry About Project Management Features
#
#                                                     body  \
# 0      Sehr geehrtes Support-Team,\n\nich möchte eine...
# 1      Dear Customer Support Team,\n\nI am writing to...
# 2      Dear Customer Support Team,\n\nI hope this mes...
# 3      Dear Customer Support Team,\n\nI hope this mes...
# 4      Dear Support Team,\n\nI hope this message reac...
# ...                                                  ...
# 28582  The data analytics tool experiences sluggish p...
# 28583  Es gab einen Datensperrungsunfall, bei dem ung...
# 28584  Wichtigere Sitzungen wurden unterbrochen durch...
# 28585  Requesting an update on the integration featur...
# 28586  Looking for detailed information on the projec...
#
#                                                   answer      type  \
# 0      Vielen Dank für die Meldung des kritischen Sic...  Incident
# 1      Thank you for reaching out, <name>. We are awa...  Incident
# 2      Thank you for your inquiry. Our products suppo...   Request
# 3      We appreciate you reaching out with your billi...   Request
# 4      Thank you for your inquiry. Our product suppor...   Problem
# ...                                                  ...       ...
# 28582  We are addressing the performance issue with t...  Incident
# 28583  Ich kann Ihnen bei dem Datensperrungsunfall he...  Incident
# 28584  Sehr geehrte/r [Name], leider wurde das Proble...  Incident
# 28585  Received your request for updates on the integ...    Change
# 28586  Dear [Name], thank you for your email regardin...   Request
#
#                        queue priority language  version        tag_1  \
# 0          Technical Support     high       de       51     Security
# 1          Technical Support     high       en       51      Account
# 2      Returns and Exchanges   medium       en       51      Product
# 3       Billing and Payments      low       en       51      Billing
# 4        Sales and Pre-Sales   medium       en       51      Product
# ...                      ...      ...      ...      ...          ...
# 28582      Technical Support     high       en      400  Performance
# 28583        Product Support     high       de      400     Security
# 28584        Human Resources      low       de      400          Bug
# 28585             IT Support     high       en      400      Feature
# 28586      Technical Support      low       en      400      Feature
#
#                tag_2         tag_3          tag_4         tag_5 tag_6 tag_7  \
# 0             Outage    Disruption    Data Breach           NaN   NaN   NaN
# 1         Disruption        Outage             IT  Tech Support   NaN   NaN
# 2            Feature  Tech Support            NaN           NaN   NaN   NaN
# 3            Payment       Account  Documentation      Feedback   NaN   NaN
# 4            Feature      Feedback   Tech Support           NaN   NaN   NaN
# ...              ...           ...            ...           ...   ...   ...
# 28582             IT  Tech Support            NaN           NaN   NaN   NaN
# 28583             IT  Tech Support            Bug           NaN   NaN   NaN
# 28584    Performance       Network             IT  Tech Support   NaN   NaN
# 28585             IT  Tech Support            NaN           NaN   NaN   NaN
# 28586  Documentation      Feedback             IT           NaN   NaN   NaN
#
#       tag_8
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ...     ...
# 28582   NaN
# 28583   NaN
# 28584   NaN
# 28585   NaN
# 28586   NaN
#
# [28587 rows x 16 columns]

# %% [markdown]
# ### Quality checking the dataset
#
# We wanted to see how clean and complete this dataset was. We were looking at the shape of the table, missing values, if dimensions were in appropriate datatypes, how much memory they used, and if any further information could be gathered from descriptive statistics.

# %%
# Information about the dataset
print("What is the shape of my table?")
print(df.shape)
print("\nAre there any missing values in each dimension?")
print(df.isna().sum().sort_values())
print("\nWhat is the datatype of each column?")
print(df.dtypes)
print("\nHow many bytes does each column use?")
print(df.memory_usage())
print("\nWhat are the initial stats of the dataframe?")
print(df.describe())
# Out:
# What is the shape of my table?
# (28587, 16)
#
# Are there any missing values in each dimension?
# body            0
# type            0
# queue           0
# priority        0
# language        0
# version         0
# tag_1           0
# answer          7
# tag_2          13
# tag_3         136
# tag_4        3058
# subject      3838
# tag_5       14042
# tag_6       22713
# tag_7       26547
# tag_8       28022
# dtype: int64
#
# What is the datatype of each column?
# subject     object
# body        object
# answer      object
# type        object
# queue       object
# priority    object
# language    object
# version      int64
# tag_1       object
# tag_2       object
# tag_3       object
# tag_4       object
# tag_5       object
# tag_6       object
# tag_7       object
# tag_8       object
# dtype: object
#
# How many bytes does each column use?
# Index          132
# subject     228696
# body        228696
# answer      228696
# type        228696
# queue       228696
# priority    228696
# language    228696
# version     228696
# tag_1       228696
# tag_2       228696
# tag_3       228696
# tag_4       228696
# tag_5       228696
# tag_6       228696
# tag_7       228696
# tag_8       228696
# dtype: int64
#
# What are the initial stats of the dataframe?
#             version
# count  28587.000000
# mean     278.382027
# std      165.962935
# min       51.000000
# 25%       52.000000
# 50%      400.000000
# 75%      400.000000
# max      400.000000

# %% [markdown]
# Continuing on with the quality checks, we wanted to confirm how many unique values there were under each dimension. This would save time later on by avoiding manual processing of the dataset to identify these findings.

# %%
# Loop to extract all unique values from each column in df
for column in df.columns:
    unique_values = df[column].sort_values(ascending=True).unique()
    length = len(unique_values)
    print(f"There were {length} unique values in {column}: {unique_values}")
    print("")
# Out:
# There were 24750 unique values in subject: [' Assistance Request'
#  ' Bitte um Ausführliche Informationen zur Datenaufbereitungsdienstleistung'
#  ' Datenschutzverletzung in Krankenhaus-Systemen ' ...
#  'Übersicht der digitalen Kampagnen'
#  'Überwachung medizinischer Daten in Krankenhaus-Systemen' nan]
#
# There were 28587 unique values in body: [' Assistance Requested' ' Assistance Required' ' Assistance needed' ...
#  'wishes to enhance data analysis tools for better optimization of decision-making processes for financial strategies to achieve better results.'
#  'Änderungen in den Datenanalyseberichten wurden bemerkt. Obwohl die Berichte neu ausgeführt wurden, bestehen weiterhin Probleme mit den Dateneingaben. Neueste Software-Updates könnten der Grund sein.'
#  'Überarbeitung der Datenanalyse, um Investitionen zu verbessern']
#
# There were 28581 unique values in answer: [' Nehmen wir diesen Fall ernst. Bitte bereiten Sie zusätzliche Details des Vorfalls vor und rufen Sie uns unter <tel_num> an. Wir werden die nächsten Schritte zur Sicherung der Systeme besprechen.'
#  ' escalate the incident to the cybersecurity team for investigation and prompt resolution of the data breach'
#  ' escalate the issue to the technical support team by contacting <tel_num>, collect relevant information, and provide a resolution to address the slowdowns in the investment data analytics platform.'
#  ...
#  'Überprüfung und Umsetzung verbesserter Verschlüsselungsmethoden sowie der Zugriffskontrollen in den beteiligten Systemen, um die Vertraulichkeit und Integrität sensibler Patientendaten sicherzustellen. Zudem soll der Fortschritt bei den Datensicherheitsprotokollen kommuniziert werden.'
#  'überprüfe E-Mail bezüglich niedriger Umwandlungsrate für digitale Marketingkampagnen. um den genauen Sachverhalt besser zu verstehen, bespreche gerne aktuelle Strategien und Ziele. Könnten Sie bitte mehr über bereits getroffene Anpassungen berichten? Anrufen Sie bitte unter <tel_num>, um eine Diskussion über mögliche Lösungen zu vereinbaren.'
#  nan]
#
# There were 4 unique values in type: ['Change' 'Incident' 'Problem' 'Request']
#
# There were 10 unique values in queue: ['Billing and Payments' 'Customer Service' 'General Inquiry'
#  'Human Resources' 'IT Support' 'Product Support' 'Returns and Exchanges'
#  'Sales and Pre-Sales' 'Service Outages and Maintenance'
#  'Technical Support']
#
# There were 3 unique values in priority: ['high' 'low' 'medium']
#
# There were 2 unique values in language: ['de' 'en']
#
# There were 3 unique values in version: [ 51  52 400]
#
# There were 116 unique values in tag_1: ['API' 'API Integration' 'Access' 'Accessibility' 'Account' 'Accounting'
#  'Agile' 'Alert' 'Analysis' 'Analytics' 'Audio' 'Backup' 'Billing'
#  'Bluetooth' 'Bug' 'Business' 'Change' 'Communication' 'Compliance'
#  'Configuration' 'Connectivity' 'Crash'
#  'Crash,Performance,Outage,Disruption,Recovery,Server,DataProcessing'
#  'Customer' 'Customer Service' 'Customer Support' 'Data' 'Data Analysis'
#  'Data Discrepancy' 'Data Inconsistency' 'Data Loss' 'Data inconsistency'
#  'Database' 'Delivery' 'Digital Strategy' 'Display' 'Disruption'
#  'Documentation' 'ERP' 'Employee' 'Feature' 'Feedback' 'Finance'
#  'Firewall' 'Functionality' 'HR' 'Hardware' 'Health' 'IT' 'Infrastructure'
#  'Inquiry' 'Integration' 'Investment' 'Investment Strategy' 'Kubernetes'
#  'Lead' 'License' 'Login' 'Maintenance' 'Marketing' 'Medical' 'Network'
#  'Notification' 'Order' 'Organization' 'Outage' 'Outlook' 'Payment'
#  'Performance' 'Performance,Bug,Disruption,Security'
#  'Performance,Disruption,IT,Tech Support'
#  'Performance,Disruption,Outage,Monitoring,Analysis'
#  'Performance,Disruption,Outage,Support,Integration'
#  'Performance,Disruption,Support'
#  'Performance,Feature,Documentation,Feedback'
#  'Performance,Outage,Disruption,Recovery,Marketing,Agentur,Analyse'
#  'Performance,Security,Feature,Documentation' 'Pricing' 'Printer'
#  'Process Improvement' 'Product' 'Project' 'Project Management' 'Recovery'
#  'Refund' 'Return' 'Sales' 'Salesforce' 'Security'
#  'Security,IT,Tech Support'
#  'Security,IT,Tech Support,Data Privacy,Regulation,Patient Data,Threat Prevention'
#  'Security,Outage,Disruption,Recovery,IT,Tech Support' 'Server' 'Service'
#  'Shipping' 'Smart Home' 'Software' 'Software Conflict' 'Software Support'
#  'Software Update' 'Strategy' 'Support' 'Synchronization' 'Systemausfall'
#  'Team Organization' 'Tech Support' 'Technical Support' 'Touchscreen'
#  'Training' 'Troubleshooting' 'UI' 'Urgency' 'User Interface' 'Video'
#  'Virus' 'Warranty']
#
# There were 257 unique values in tag_2: ['AI' 'API' 'AWS' 'Access' 'Access Control' 'Accessibility' 'Account'
#  'Accuracy' 'ActiveCampaign' 'Adjustment' 'Admin' 'Advertising' 'Agency'
#  'Alarm' 'Alert' 'Analysis' 'Analytics' 'Assistance' 'Attack'
#  'Authentication' 'Automation' 'Backup' 'Billing' 'Brand'
#  'Brand Awareness' 'Brand Development' 'Brand Expansion' 'Brand Growth'
#  'Brand Management' 'Brand Marketing' 'Brand Promotion' 'Brand Visibility'
#  'Branding' 'Breach' 'Budget' 'Bug' 'Business' 'Business Development'
#  'Business Expansion' 'Business Information' 'CRM' 'Campaign'
#  'Campaign Effectiveness' 'Campaign Optimization' 'Campaigns' 'Cloud'
#  'Cloud Native' 'Cloud Platform' 'Cloud-Native' 'Collaboration'
#  'Compatibility' 'Compliance' 'Confidentiality' 'Configuration'
#  'Connectivity' 'Coordination' 'Cost' 'Crash' 'Customer Data'
#  'Customer Engagement' 'Customer Service' 'Customer Support'
#  'Cyber Attack' 'Cyberattack' 'Cybersecurity' 'Dashboard' 'Data'
#  'Data Access' 'Data Accuracy' 'Data Analysis' 'Data Analytics'
#  'Data Backup' 'Data Breach' 'Data Discrepancy' 'Data Encryption'
#  'Data Exposure' 'Data Integration' 'Data Integrity' 'Data Issue'
#  'Data Leak' 'Data Loss' 'Data Management' 'Data Privacy'
#  'Data Processing' 'Data Protection' 'Data Security' 'Data Storage'
#  'Data Sync' 'Data Validation' 'Data breach' 'DataLeak' 'DataProtection'
#  'Database' 'Delay' 'Deployment' 'Device' 'Digital' 'Digital Branding'
#  'Digital Campaign' 'Digital Campaigns' 'Digital Expansion'
#  'Digital Marketing' 'Digital Strategy' 'Digital Transformation'
#  'Discrepancy' 'Display' 'Disruption' 'Documentatio' 'Documentation'
#  'Documentatoin' 'Electronics' 'Email' 'Email Marketing' 'Employee'
#  'Encryption' 'Engagement' 'Enhancement' 'Error' 'Exchange' 'Feature'
#  'Feedback' 'Finance' 'Financial' 'Financial Institution'
#  'Financial Planning' 'Firmware' 'Growth' 'Guidance' 'HR' 'Hadoop'
#  'Hardware' 'Health' 'Healthcare' 'Hospital Systems' 'IT' 'Improvement'
#  'Incident' 'Information' 'Information Privacy' 'Infrastructure' 'Inquiry'
#  'Integration' 'Investigation' 'Investment' 'Investment Analysis'
#  'Investment Strategy' 'Invoice' 'Issue' 'Issue Resolution' 'Lead' 'Login'
#  'Magento' 'Maintenance' 'Malware' 'Management' 'Marketing' 'Medical'
#  'Medical Data' 'Medical Information' 'Microservice' 'Monitoring'
#  'Network' 'Netzwerk' 'Notification' 'Onboarding' 'Online' 'Optimization'
#  'Outage' 'Outdated Software' 'Patient' 'Payment' 'Performance' 'Phishing'
#  'Policy' 'Price' 'Pricing' 'Privacy' 'Process' 'Process Improvement'
#  'Process Integration' 'Process Update' 'Product' 'Product Integration'
#  'Productivity' 'Project' 'Project Management' 'Promotion' 'RAID'
#  'Recovery' 'Refund' 'Reliability' 'Replacement' 'Request' 'Return' 'Risk'
#  'SEO' 'SaaS' 'Sales' 'Salesforce' 'Scalability' 'Security' 'Server'
#  'Server Overload' 'Service' 'Service Disruption' 'Service Impact'
#  'Shipment' 'Social Media' 'Software' 'Software Compatibility'
#  'Software Conflict' 'Software Error' 'Software Incompatibility'
#  'Software Integration' 'Software Issue' 'Software Update'
#  'SoftwareIntegration' 'Solution' 'Stability' 'Strategy' 'Subscription'
#  'Support' 'Swap' 'Synchronization' 'System' 'System Congestion'
#  'System Integration' 'System Issue' 'System Update' 'Team' 'Tech'
#  'Tech Support' 'Technical' 'Technical Difficulty' 'Technical Issue'
#  'Technical Support' 'Technology' 'Threat' 'Training' 'Troubleshooting'
#  'UI/UX' 'Update' 'Upgrade' 'Urgent' 'Usability' 'User Experience'
#  'User Interface' 'VPN' 'Virus' 'Visibility' 'Vulnerability' 'Warranty'
#  'Website' 'Website Issue' 'Windows' 'Workflow' nan]
#
# There were 393 unique values in tag_3: ['API' 'API Integration' 'AWS' 'Access' 'Access Control' 'Access Issue'
#  'Access Management' 'Account' 'Accounting' 'Accuracy' 'Advertising'
#  'Agency' 'Alarm' 'Alert' 'Algorithm' 'Algorithm Change'
#  'Algorithm Update' 'Analysis' 'Analytics' 'Anleitung' 'Application Issue'
#  'Assistance' 'Audience' 'Audience Targeting' 'Audio' 'Audit'
#  'Authentication' 'Authorization' 'Automation' 'Azure' 'Backup'
#  'Best Practice' 'Billing' 'Brand' 'Brand Awareness' 'Brand Development'
#  'Brand Engagement' 'Brand Enhancement' 'Brand Expansion' 'Brand Growth'
#  'Brand Management' 'Brand Visibility' 'Branding' 'Breach'
#  'Browser Compatibility' 'Budget' 'Bug' 'Business Expansion'
#  'Business Growth' 'Business Strategy' 'Cache' 'Campaign'
#  'Campaign Analysis' 'Campaign Management' 'Campaign Performance'
#  'Campaign Strategy' 'Campaigns' 'Capability' 'Cassandra' 'Cisco IOS'
#  'Cloud' 'Cloud Platform' 'Cloud Services' 'Cloud Software' 'Cloud-Native'
#  'Collaboration' 'Communication' 'Community' 'Compatibility' 'Compliance'
#  'Confidentiality' 'Configuration' 'Conflict' 'Connectivity'
#  'Consultation' 'Consulting' 'Content' 'Content Creation'
#  'Content Strategy' 'Coordination' 'Cost Analysis' 'Crash'
#  'Customer Engagement' 'Customer Service' 'Customer Support'
#  'Customization' 'Cyber Attack' 'Cyber Threat' 'Cyberattack'
#  'Cybersecurity' 'Dashboard' 'Data' 'Data Access' 'Data Accuracy'
#  'Data Analysis' 'Data Analytics' 'Data Breach' 'Data Discrepancy'
#  'Data Encryption' 'Data Exposure' 'Data Inconsistency' 'Data Integration'
#  'Data Integrity' 'Data Issue' 'Data Leakage' 'Data Management'
#  'Data Monitoring' 'Data Privacy' 'Data Processing' 'Data Protection'
#  'Data Quality' 'Data Security' 'Data Synchronization' 'Data Tools'
#  'Data Validation' 'Data Visualization' 'Data breach' 'DataProtection'
#  'Database' 'Decision Making' 'Delivery' 'Deployment' 'Development'
#  'Device' 'Digital' 'Digital Advertising' 'Digital Campaign'
#  'Digital Campaigns' 'Digital Channels' 'Digital Expansion'
#  'Digital Growth' 'Digital Marketing' 'Digital Platform'
#  'Digital Resources' 'Digital Signature' 'Digital Strategy'
#  'Digital Tactics' 'Digital Tool' 'Digital Tools' 'Digital Transformation'
#  'Discord' 'Discount' 'Discrepancy' 'Display' 'Dispute' 'Disruption'
#  'Disruption,IT' 'Docker' 'Document' 'Documentation' 'Driver' 'ERP'
#  'Efficiency' 'Electronics' 'Email' 'Employee' 'Encryption' 'Engagement'
#  'Enhancement' 'Equipment' 'Error' 'Failure' 'Feature' 'Feedback'
#  'Feeedback' 'Fehler' 'Finance' 'Financial' 'Financial Loss'
#  'Financial Services' 'Financial Systems' 'Firewall' 'Firmware' 'GCP'
#  'Gateway' 'Google Nest Wifi' 'Growth' 'Guidance' 'Guide' 'HIPAA' 'HR'
#  'Hardware' 'Hardware Conflict' 'Health' 'Health Data' 'HealthIT'
#  'Healthcare' 'Healthcare IT' 'Hospital' 'Hospital Infrastructure'
#  'Hospital Networks' 'Hospital System' 'Hospital Systems' 'IT'
#  'IT Support' 'Implementation' 'Improvement' 'Incident' 'Industry Trends'
#  'Information' 'Infrastructure' 'Inquiry' 'Installation' 'Instruction'
#  'Integration' 'Integration Error' 'Integration Issue'
#  'Integration Problem' 'Interface' 'Investigation' 'Investment'
#  'Investment Analytics' 'Investment Optimization' 'Investment Strategy'
#  'Investment analysis' 'Invoice' 'IoT' 'Issue' 'Lead' 'License' 'Login'
#  'Machine Learning' 'Maintenance' 'Malware' 'Market Trend' 'Marketing'
#  'Marketing Automation' 'Medical' 'Medical Data' 'Medical Devices'
#  'Medical Documentation' 'Medical Information' 'Medical Records'
#  'Medical Sector' 'Medical Systems' 'Memory' 'Microservices'
#  'Microsoft SQL Server' 'Monitoring' 'Network' 'Network Disruption'
#  'Network Security' 'Notification' 'Online Security' 'Online Visibility'
#  'Optimization' 'Order' 'Organization' 'Organizational Structure' 'Outage'
#  'Outdated' 'Outdated Encryption' 'Outdated Procedures'
#  'Outdated Protocol' 'Outdated Software' 'Outdated Systems'
#  'Outdated Version' 'Patch' 'Patient Data' 'Patient Information' 'Payment'
#  'Payment Gateway' 'Performance' 'Phishing' 'Platform' 'Platform Update'
#  'Plugin' 'Portfolio' 'PostgreSQL' 'Pricing' 'Printer' 'Privacy' 'Problem'
#  'Process' 'Process Automation' 'Process Improvement' 'Product'
#  'Product Line' 'Product Platform' 'Product Promotion' 'Productivity'
#  'Project' 'Project Management' 'Promotion' 'Protection' 'Protocol'
#  'Python' 'Query' 'Query Optimization' 'Records' 'Recovery' 'Redis'
#  'Refund' 'Reliability' 'Report' 'Reporting' 'Request' 'Research'
#  'Response' 'Return' 'Revenue' 'Risk' 'Risk Management' 'Ruby on Rails'
#  'SAP' 'SEO' 'SQL' 'SaaS' 'SaaS Platform' 'Sales' 'Scalability' 'Security'
#  'Security Breach' 'Security Management' 'Security Update' 'Server'
#  'Server Overload' 'Server Restart' 'Service' 'Services' 'Shipment'
#  'Slow Response' 'Social Media' 'Software' 'Software Compatibility'
#  'Software Conflict' 'Software Development Kit' 'Software Incompatibility'
#  'Software Integration' 'Software Issue' 'Software Konflikt'
#  'Software Limitation' 'Software Update' 'Software Version Mismatch'
#  'Software Vulnerability' 'Sound' 'Stability' 'Strategy' 'Subscription'
#  'Support' 'Swap' 'Sync Issue' 'Synchronization' 'System'
#  'System Calibration' 'System Configuration' 'System Conflict'
#  'System Error' 'System Failure' 'System Integration' 'System Issue'
#  'System Resilience' 'System Update' 'System Upgrade'
#  'System Vulnerability' 'System details' 'Targeting' 'Task Assignment'
#  'Tech Support' 'Technical Issue' 'Technical Malfunction'
#  'Technical Support' 'Technology' 'Testing' 'Threat' 'Ticket'
#  'Touchscreen' 'Training' 'Transaction' 'Troubleshooting' 'Tutorial' 'UI'
#  'USB' 'Unauthorized Access' 'Update' 'Upgrade' 'User Experience'
#  'User Guide' 'User Interface' 'Utility' 'VPN' 'Verification' 'Violation'
#  'Virus' 'Visualization' 'Vulnerability' 'Warranty' 'Website'
#  'Website Traffic' 'Windows' 'Workflow' 'macOS' nan]
#
# There were 555 unique values in tag_4: ['AI' 'API' 'Access' 'Access Control' 'Access Management' 'Accessibility'
#  'Account' 'Accounting' 'Accuracy' 'Adobe' 'Advertisement' 'Advertising'
#  'Advice' 'Advisory' 'Agency' 'Airtable' 'Alarm' 'Alert' 'Algorithm'
#  'Analysis' 'Analysis Platform' 'Analytics' 'Analytics Platform'
#  'Antivirus' 'App' 'App Issue' 'App Update' 'Application' 'Architecture'
#  'Assistance' 'Attack' 'Audience' 'Audience Engagement' 'Audio'
#  'Audio Editing' 'Audit' 'Authentication' 'Automation' 'Availability'
#  'Azure' 'Backend' 'Backup' 'Best Practice' 'Best Practices' 'Billing'
#  'Brand' 'Brand Awareness' 'Brand Development' 'Brand Engagement'
#  'Brand Expansion' 'Brand Growth' 'Brand Messaging' 'Brand Presence'
#  'Brand Recognition' 'Brand Strategy' 'Brand Visibility' 'BrandExpansion'
#  'Branding' 'Breach' 'Browser' 'Budget' 'Bug' 'Business'
#  'Business Analysis' 'Business Development' 'Business Expansion'
#  'Business Growth' 'Business Performance' 'CRM' 'Cache' 'Cache Problem'
#  'Campaign' 'Campaign Analysis' 'Campaign Delay' 'Campaign Management'
#  'Campaigns' 'Case Study' 'Certification' 'Challenge' 'Clarification'
#  'Cloud' 'Cloud Infrastructure' 'Cloud SaaS' 'Cloud-Native'
#  'Collaboration' 'Communication' 'Compatibility' 'Compliance'
#  'Confidentiality' 'Configuration' 'Connection Issue' 'Connectivity'
#  'Consultation' 'Consulting' 'Container Services' 'Content'
#  'Content Creation' 'Content Development' 'Content Issue'
#  'Content Management' 'Content Marketing' 'Content Strategy' 'Control'
#  'Coordination' 'Cost' 'Cost analysis' 'Crash' 'Credential' 'Custom Plan'
#  'Customer' 'Customer Data' 'Customer Engagement' 'Customer Experience'
#  'Customer Interaction' 'Customer Service' 'Customer Support'
#  'Customer Targeting' 'Customization' 'Cyber' 'Cyber Threat'
#  'Cyber Threats' 'Cyberattack' 'Cybersecurity' 'DSLR' 'Dashboard' 'Data'
#  'Data Access' 'Data Accessibility' 'Data Analysis' 'Data Analysis Tool'
#  'Data Analytics' 'Data Availability' 'Data Backup' 'Data Breach'
#  'Data Discrepancy' 'Data Encryption' 'Data Entry' 'Data Error'
#  'Data Handling' 'Data Inconsistency' 'Data Integration' 'Data Integrity'
#  'Data Issue' 'Data Leak' 'Data Loss' 'Data Management' 'Data Pipeline'
#  'Data Platform' 'Data Privacy' 'Data Processing' 'Data Protection'
#  'Data Regulation' 'Data Security' 'Data Storage' 'Data Synchronization'
#  'Data-Driven Decision' 'DataPipeline' 'DataProcessing' 'DataProtection'
#  'Database' 'Decision Making' 'Decision Support' 'Decision-Making' 'Delay'
#  'Deployment' 'Design' 'Development' 'Diagnostics' 'Digital'
#  'Digital Campaign' 'Digital Campaigns' 'Digital Marketing'
#  'Digital Platform' 'Digital Space' 'Digital Strategy' 'Digital Tactics'
#  'Digital Tool' 'Digital Tools' 'Digital Transformation'
#  'DigitalMarketing' 'Discount' 'Discrepancy' 'Disruption' 'Docker'
#  'Document' 'Documentation' 'Documentations' 'Driver' 'Driver Issue'
#  'Drupal' 'E-commerce' 'ERP' 'Editing' 'Efficiency' 'Email'
#  'Email Marketing' 'Emergency' 'Employee' 'Encryption' 'Engagement'
#  'Enhancement' 'Error' 'Evaluation' 'Exchange' 'External Device' 'Feature'
#  'Feedback' 'Fees' 'Finance' 'Financial' 'Financial Data' 'Financial Firm'
#  'Financial Institution' 'Financial Loss' 'Financial Sector'
#  'Financial Services' 'Firewall' 'Firmware' 'Flexibility' 'Forecast'
#  'Free Trial' 'GCP' 'Gateway' 'Growth' 'Guidance' 'HIPAA' 'HR' 'Hardware'
#  'Health' 'Health Data' 'Health IT' 'Health Sector' 'Healthcare'
#  'Healthcare Data' 'Hospital' 'Hospital Data' 'Hospital IT'
#  'Hospital Infrastructure' 'Hospital Network' 'Hospital Orders'
#  'Hospital Records' 'Hospital Security' 'Hospital System'
#  'Hospital Systems' 'IT' 'IT Support' 'Implementation' 'Improvement'
#  'Inaccuracy' 'Incident' 'Incident Response' 'Indexing' 'Industry Trend'
#  'Influencer' 'Information' 'Information Security' 'Infrastructure'
#  'Injury' 'Innovation' 'Inquiry' 'Insight' 'Instruction' 'Instructions'
#  'Integration' 'Integration Issue' 'Integration Problem' 'Integrity'
#  'Internet' 'Investigation' 'Investment' 'Investment Analysis'
#  'Investment Analysis Tool' 'Investment Data Analytics'
#  'Investment Optimization' 'Investment Strategies' 'Investment Strategy'
#  'Invoice' 'IoT' 'Issue' 'Issue Analysis' 'Kubernetes' 'Lead' 'License'
#  'Load' 'Login' 'Machine Learning' 'Maintenance' 'Malware' 'Management'
#  'Market Analysis' 'Market Growth' 'Market Trend' 'Market Trends'
#  'Marketing' 'Media Management' 'Medical' 'Medical Data'
#  'Medical Information' 'Medical Product' 'Medical Records'
#  'Medical Systems' 'Memory' 'Memory Leak' 'Messaging' 'Microservice'
#  'Microservices' 'Microsoft' 'Microsoft Dynamics' 'Model' 'Modeling'
#  'Monitoring' 'Navigation' 'Network' 'Network Security' 'Node.js'
#  'Notification' 'Nutzung' 'Offer' 'Online Advertising' 'Online Presence'
#  'Online Visibility' 'Optimization' 'Oracle' 'Order' 'Organization'
#  'Organizational Change' 'Outage' 'Outdated' 'Outdated Security'
#  'Outdated Software' 'Outdated Version' 'Outlook' 'Outreach' 'PHP'
#  'Package' 'Packages' 'Partnership' 'Password' 'Patch'
#  'Patient Confidentiality' 'Patient Data' 'Patient Information' 'Payment'
#  'Payment Gateway' 'Payment Methods' 'Performance' 'Permission' 'Phishing'
#  'Plan' 'Plans' 'Platform' 'Platform Issue' 'Platform Optimization'
#  'Platform Security' 'Platform Update' 'Plugin' 'Policy' 'Portfolio'
#  'Portfolio Management' 'Portfolio Return' 'Prediction Error' 'Pricing'
#  'Priority' 'Privacy' 'Procedure' 'Process' 'Product'
#  'Product Integration' 'Product Line' 'Productivity' 'Project Management'
#  'Promotion' 'Promotional Offer' 'Protection' 'Protocol' 'Protocols'
#  'Python' 'Real-Time Data' 'Real-time' 'Real-time Data'
#  'Real-time Insights' 'Real-time Monitoring' 'Reboot' 'Rebooting'
#  'Reconciliation' 'Recovery' 'Redis' 'Refund' 'Regulatory'
#  'Regulatory Compliance' 'Reinstallation' 'Reliability' 'Report Issue'
#  'Reporting' 'Reputation' 'Resolution' 'Resource Management' 'Resources'
#  'Response Time' 'Return' 'Risk' 'Risk Management' 'Router' 'SAP ERP'
#  'SDK' 'SEO' 'SaaS' 'Safeguarding' 'Safety' 'Sales' 'Scalability'
#  'Scanner' 'Security' 'Security Breach' 'Security Improvement'
#  'Security Measures' 'Security Protocol' 'Security Standards'
#  'Segmentation' 'Sensitive Data' 'Server' 'Server Overload'
#  'Server overload' 'Service' 'Service Improvement' 'Service Inquiry'
#  'Service Package' 'Service Quality' 'Setup' 'Setup Fee'
#  'Shopping Behavior' 'Sluggishness' 'Smart Home' 'Social Media'
#  'Social Media Management' 'Software' 'Software Compatibility'
#  'Software Conflict' 'Software Development' 'Software Development Kit'
#  'Software Error' 'Software Fehler' 'Software Integration'
#  'Software Issue' 'Software Patch' 'Software Product' 'Software Update'
#  'Software update' 'SoftwareIntegration' 'SoftwareProblem'
#  'SoftwareUpdate' 'Solution' 'Solutions' 'Speed' 'Sprint' 'Stability'
#  'Standard' 'Storage' 'Strategy' 'Subscription' 'Success Story' 'Support'
#  'Synchronisation' 'Synchronization' 'System' 'System Application'
#  'System Cache' 'System Challenge' 'System Conflict' 'System Delay'
#  'System Diagnostics' 'System Downtime' 'System Driver'
#  'System Enhancement' 'System Error' 'System Failure' 'System Guidance'
#  'System Implementation' 'System Integration' 'System Integrity'
#  'System Issue' 'System Load' 'System Log' 'System Optimization'
#  'System Outage' 'System Overload' 'System Patch' 'System Problem'
#  'System Reboot' 'System Restart' 'System Scan' 'System Security'
#  'System Slowdown' 'System Slowness' 'System Synchronization'
#  'System Troubleshooting' 'System Update' 'System Usage' 'System Version'
#  'System Vulnerability' 'SystemVulnerability' 'Target Audience'
#  'Targeting' 'Tech Sector' 'Tech Support' 'Technical Difficulty'
#  'Technical Issue' 'Technical Problem' 'Technical Requirement'
#  'Technical Support' 'Technology' 'Telemedicine' 'Testing'
#  'Third-party Application' 'Threat' 'Threat Analysis' 'Threat Detection'
#  'Threat Prevention' 'Ticket' 'Tool' 'Tool Integration' 'Tool Investment'
#  'Tools' 'Traffic' 'Training' 'Transaction' 'Troubleshooting' 'Tutorial'
#  'UI' 'Ubuntu' 'Unauthorized Access' 'Unforeseen' 'Update' 'Upgrade'
#  'Urgency' 'Urgent' 'Usability' 'User Conflict' 'User Experience'
#  'User Guide' 'User Interaction' 'User Interface' 'User Management' 'VPN'
#  'Version Mismatch' 'Virus' 'Visibility' 'Visual' 'Visualization'
#  'Vulnerability' 'Warranty' 'Workflow' 'Workshop' 'Zapier' nan]
#
# There were 603 unique values in tag_5: ['API' 'AR' 'Abrechnungssystem' 'Access' 'Access Control' 'Access Log'
#  'Access Management' 'AccessManagement' 'Account' 'Accuracy' 'Adjustment'
#  'Advertising' 'Advertising Budget' 'Advice' 'Agency' 'Alert' 'Algorithm'
#  'Analysis' 'Analytics' 'Analytics Platform' 'Android' 'Antivirus'
#  'Application' 'Application Issue' 'Assessment' 'Assistance' 'Audience'
#  'Audience Engagement' 'Audience Insights' 'Audience Mismatch'
#  'Audience Reach' 'Audience Segmentation' 'Audience Targeting' 'Audit'
#  'Auditing' 'Authentication' 'Authorization' 'Automation' 'Availability'
#  'Backup' 'Behavior' 'Benefit' 'Best Practice' 'Best Practices' 'Billing'
#  'Brand' 'Brand Awareness' 'Brand Development' 'Brand Engagement'
#  'Brand Expansion' 'Brand Growth' 'Brand Visibility' 'Branding' 'Breach'
#  'Browser' 'Budget' 'Budget Reallocation' 'Bug' 'Business'
#  'Business Development' 'Business Expansion' 'Business Growth'
#  'Business Operation' 'Business Operations' 'Business Strategy' 'Cache'
#  'Cache Clearing' 'Caching' 'Caching Issue' 'Campaign'
#  'Campaign Effectiveness' 'Campaign Management' 'Campaign Performance'
#  'Campaigns' 'Capacity' 'Case Study' 'Cassandra' 'Certification'
#  'Client Engagement' 'Client Support' 'Cloud' 'Cloud Infrastructure'
#  'Cloud Service' 'Code Deployment' 'Collaboration' 'Communication'
#  'Compatibility' 'Competitiveness' 'Compliance' 'Compromise' 'Concern'
#  'Confidentiality' 'Configuration' 'Conflict' 'Connection'
#  'Connection Problem' 'Connectivity' 'Container' 'Content'
#  'Content Creation' 'Content Development' 'Content Growth' 'Content Issue'
#  'Content Management' 'Content Marketing' 'Contract' 'Coordination'
#  'Correction' 'Cost' 'Cost Analysis' 'Cost Breakdown' 'Cost Details'
#  'Crash' 'Creative' 'Creativity' 'Credential Security' 'Credentials'
#  'Critical' 'Critical Issue' 'Customer Engagement' 'Customer Experience'
#  'Customer Feedback' 'Customer Interaction' 'Customer Loyalty'
#  'Customer Service' 'Customer Support' 'Customization' 'Cyber Threat'
#  'Cyberattack' 'Cybersecurity' 'Dashboard' 'Data' 'Data Access'
#  'Data Accuracy' 'Data Analysis' 'Data Analytics' 'Data Availability'
#  'Data Breach' 'Data Discrepancy' 'Data Exchange' 'Data Inconsistency'
#  'Data Integration' 'Data Integrity' 'Data Issue' 'Data Management'
#  'Data Pipeline' 'Data Privacy' 'Data Processing' 'Data Protection'
#  'Data Quality' 'Data Reconciliation' 'Data Refresh' 'Data Retrieval'
#  'Data Security' 'Data Source' 'Data Storage' 'Data Synchronization'
#  'Data Traffic' 'Data Validation' 'Data Visualization'
#  'Data inconsistency' 'DataPipeline' 'DataProtection' 'DataRobot'
#  'Database' 'Datenanalyse' 'Debugging' 'Decision' 'Decision Making'
#  'Decision Support' 'Decision-Making' 'Delay' 'Dependencies' 'Deployment'
#  'Design' 'Development' 'Device' 'Device Security' 'Diagnostic'
#  'Diagnostics' 'Difficulty' 'Digital' 'Digital Application'
#  'Digital Campaign' 'Digital Campaigns' 'Digital Channel'
#  'Digital Footprint' 'Digital Growth' 'Digital Marketing'
#  'Digital Platform' 'Digital Presence' 'Digital Services'
#  'Digital Strategy' 'Digital Tactics' 'Digital Tool' 'Digital Tools'
#  'DigitalMarketing' 'Discount' 'Discrepancy' 'Disruption' 'Documentation'
#  'Downtime' 'Driver' 'E-signature' 'EMR' 'ERP' 'Effectiveness'
#  'Efficiency' 'Email' 'Email Marketing' 'Employee' 'Encryption'
#  'Engagement' 'Enhancement' 'Environment' 'Error' 'Evaluation' 'Exchange'
#  'Expansion' 'Exposure' 'External Service' 'Feature' 'Fee' 'Feedback'
#  'Finance' 'Financial' 'Financial Analysis' 'Financial Assistance'
#  'Financial Decision' 'Financial Industry' 'Financial Institution'
#  'Financial Loss' 'Financial Reporting' 'Financial Risk'
#  'Financial Services' 'Firewall' 'Firmware' 'Fix' 'Gateway' 'Glitch'
#  'Google Keep' 'Growth' 'Guidance' 'Guide' 'H2O.ai' 'HIPAA' 'Hardware'
#  'Health Data' 'Healthcare' 'Healthcare Data' 'High Priority' 'Hospital'
#  'Hospital Environment' 'Hospital Infrastructure' 'Hospital System'
#  'Hospital Systems' 'HospitalInfrastructure' 'HospitalSystem' 'IT'
#  'Impact' 'Implementation' 'Improvement' 'Inaccuracy' 'Incident'
#  'Incident Response' 'Inconsistency' 'Industry Trend' 'Influencer'
#  'Information' 'Information Security' 'Infrastructure' 'Infrastruktur'
#  'Initiative' 'Innovation' 'Inquiry' 'Insight' 'Insights' 'Inspection'
#  'Instability' 'Installation' 'Instruction' 'Integration'
#  'Integration Challenges' 'Integration Issue' 'Integrity' 'Interaction'
#  'Internal Review' 'Intrusion Detection' 'Investigation' 'Investment'
#  'Investment Analysis' 'Investment Optimization' 'Investment Strategies'
#  'Investment Strategy' 'Invoice' 'Issue' 'Issue Investigation'
#  'Issue investigation' 'Knowledge Base' 'Kubernetes' 'Lead' 'Leadership'
#  'Load Balancing' 'Log' 'Log Issue' 'Log Rollback' 'Login'
#  'Machine Learning' 'Maintenance' 'Major' 'Malfunction' 'Malware'
#  'Management' 'Market' 'Market Analysis' 'Market Awareness'
#  'Market Development' 'Market Trend' 'Market Trends' 'Marketing'
#  'Marketing Strategy' 'Marketing Team' 'Media' 'Medical' 'Medical Data'
#  'Medical Devices' 'Medical Information' 'Medical Records'
#  'Medical Support' 'Medical System' 'MedicalData' 'Memory' 'Messaging'
#  'Methodology' 'Metrics' 'Microservice' 'Microservices'
#  'Misclassification' 'Misconfiguration' 'Mitigation' 'Model' 'Monitoring'
#  'Navigation' 'Network' 'Network Security' 'Netzwerk' 'Notification' 'OS'
#  'Office Equipment' 'Onboarding' 'Online' 'Online Growth'
#  'Online Marketing' 'Online Presence' 'Online Visibility' 'Operation'
#  'Operational Efficiency' 'Optimization' 'Oracle' 'Organization' 'Outage'
#  'Outcome' 'Outdated' 'Outdated Content' 'Outdated Protocol'
#  'Outdated Security' 'Outreach' 'Packages' 'Partnership' 'Password'
#  'Password Reset' 'Patch' 'Patient' 'Patient Data' 'Patient Information'
#  'Patient Privacy' 'Payment' 'Payment Gateway' 'Payment Method'
#  'Payment Methods' 'Performance' 'Permission' 'Phishing' 'Plan' 'Planning'
#  'Plans' 'Platform' 'Platform Integration' 'Plugin' 'Policy' 'PostgreSQL'
#  'Predictive Analytics' 'Predictive Modeling' 'Prevention' 'Pricing'
#  'Printer' 'Privacy' 'Problem' 'Procedure' 'Process' 'Process Improvement'
#  'Process Optimization' 'Product' 'Product Improvement' 'ProductPromotion'
#  'Productivity' 'Project' 'Project Management' 'Project management'
#  'ProjectManagement' 'Promotion' 'Protection' 'Protocol' 'Protocols'
#  'Python' 'Quality' 'Query' 'Reach' 'Real-time' 'Reboot' 'Rebooting'
#  'Rebranding' 'Reconciliation' 'Recovery' 'Refund' 'Regulation'
#  'Regulations' 'Reinstallation' 'Reliability' 'Replacement' 'Report'
#  'Request' 'Research' 'Resolution' 'Resource' 'Resource Allocation'
#  'Resources' 'Restart' 'Restart Issue' 'Return' 'Revenue' 'Review' 'Risk'
#  'Risk Management' 'Root Cause' 'Router' 'SAP' 'SEO' 'SaaS' 'Safety'
#  'Safety Measures' 'Safety Patch' 'Sales' 'Scalability' 'Scaling'
#  'Security' 'Security Alert' 'Security Improvement' 'Security Measures'
#  'Security Patch' 'Security Policy' 'Security Protocols'
#  'Security Solution' 'Segmentation' 'Sensitive' 'Sensitive Data'
#  'Sensitive Information' 'Sensitive Resource' 'Server' 'Server Overload'
#  'Server Synchronization' 'Server overload' 'Service' 'Service Cache'
#  'Service Capacity' 'Service Disruption' 'Service Offerings'
#  'Service Optimization' 'Service Package' 'Setup' 'Slowdown'
#  'Smart Thermostat' 'Social Media' 'Social Media Marketing' 'Software'
#  'Software Compatibility' 'Software Conflict' 'Software Development Kit'
#  'Software Enhancement' 'Software Error' 'Software Fehler'
#  'Software Integration' 'Software Problem' 'Software Update'
#  'Software Vulnerability' 'Software incompatibility' 'SoftwareConflict'
#  'Solution' 'Specification' 'Speed' 'Stability' 'Strategy'
#  'Strategy Improvement' 'Subscription' 'Success Story' 'Support' 'Switch'
#  'Sync' 'Synchronisation' 'Synchronization' 'System' 'System\n\n'
#  'System Analysis' 'System Bottleneck' 'System Cache' 'System Check'
#  'System Compatibility' 'System Configuration' 'System Connector'
#  'System Diagnostics' 'System Driver' 'System Enhancement' 'System Error'
#  'System Improvement' 'System Integration' 'System Integrity'
#  'System Issue' 'System Optimization' 'System Overload' 'System Problem'
#  'System Reboot' 'System Restart' 'System Scan' 'System Security'
#  'System Slowdown' 'System Tracking' 'System Update'
#  'System Vulnerability' 'System Überlastung' 'SystemAccess'
#  'SystemRestart' 'Target Audience' 'Targeting' 'Team' 'Tech'
#  'Tech Support' 'Technical Assistance' 'Technical Difficulty'
#  'Technical Issue' 'Technical Problem' 'Technical Support'
#  'Technical Tools' 'Technology' 'Telemedicine' 'Test Version' 'Testing'
#  'Third Party Tool' 'Threat' 'Threat Evaluation' 'Ticket Management'
#  'Tool' 'Tools' 'Toolset' 'Traffic' 'Traffic Surge' 'Training'
#  'Transaction' 'Trend' 'Troubleshooting' 'Tutorial' 'Ubuntu'
#  'Unauthorized Access' 'Unintentional' 'Update' 'Update Issue' 'Upgrade'
#  'Urgent' 'Usability' 'Usage' 'User Experience' 'User Friendly'
#  'User Guidance' 'User Guide' 'User Manual' 'User Support' 'VPN'
#  'Validation' 'Validation Error' 'Virtual Meeting' 'Virus' 'Visibility'
#  'Visualization' 'Vulnerability' 'Warning' 'Warranty' 'Webhook' 'Webpage'
#  'Website' 'Website Optimization' 'Website Traffic' 'Windows 10'
#  'Workflow' nan]
#
# There were 576 unique values in tag_6: ['API' 'Access' 'Access Control' 'Access Difficulty' 'Access Issue'
#  'Access Management' 'Account' 'Accuracy' 'Ad Segment' 'Adjustment'
#  'Advertising' 'Advice' 'Agency' 'Alert' 'Algorithm' 'Analysis'
#  'Analysis Capability' 'Analysis Method' 'Analytics' 'Android' 'Antivirus'
#  'App Issue' 'Application' 'Approach' 'Assessment' 'Assistance' 'Audience'
#  'Audience Segment' 'Audience Segmentation' 'Audience Targeting' 'Audit'
#  'Auditing' 'Authentication' 'Automation' 'Availability' 'Awareness'
#  'Backend' 'Backup' 'Best Practice' 'Best Practices' 'Billing' 'Brand'
#  'Brand Awareness' 'Brand Campaigns' 'Brand Development' 'Brand Expansion'
#  'Brand Growth' 'Brand Management' 'Brand Messaging' 'Brand Visibility'
#  'Branding' 'Breach' 'Browser' 'Budget' 'Bug' 'Bulk Purchase' 'Business'
#  'Business Development' 'Business Expansion' 'Business Growth'
#  'Business Improvement' 'Business Information' 'Business Planning'
#  'Business Process' 'Cache' 'Cache Issue' 'Campaign'
#  'Campaign Effectiveness' 'Campaign Management' 'Campaigns' 'Cancellation'
#  'Capacity' 'Case Study' 'Certification' 'Challenge' 'Change' 'Cloud'
#  'Cloud Native' 'Code' 'Collaboration' 'Communication' 'Compatibility'
#  'Competition' 'Compliance' 'Confidentiality' 'Configuration' 'Conflict'
#  'Connection' 'Connection Issue' 'Connection Problem' 'Connectivity'
#  'Consultation' 'Containment' 'Content' 'Content Creation'
#  'Content Marketing' 'Content Review' 'Content Revision'
#  'Content Strategy' 'Conversion' 'Conversion Rate' 'Correction' 'Cost'
#  'Cost Breakdown' 'Cost Estimation' 'Cost Management' 'Cost Plan'
#  'Creative' 'Creative Content' 'Creativity' 'Credential'
#  'Credential Reset' 'Critical' 'Critical Incident' 'Critical Issue'
#  'Customer' 'Customer Engagement' 'Customer Experience'
#  'Customer Guidance' 'Customer Interaction' 'Customer Satisfaction'
#  'Customer Service' 'Customer Support' 'Customer Targeting'
#  'Customer Value' 'Customization' 'Cyber Threat' 'Cybersecurity' 'Data'
#  'Data Analysis' 'Data Analytics' 'Data Availability' 'Data Breach'
#  'Data Integration' 'Data Integrity' 'Data Issue' 'Data Pipeline'
#  'Data Privacy' 'Data Processing' 'Data Protection' 'Data Security'
#  'Data Source' 'Data Synchronization' 'Data Traffic' 'Data Validation'
#  'Data Visualization' 'DataLoss' 'DataProcessing' 'Database' 'Debugging'
#  'Decision' 'Decision Making' 'Decision-making' 'Delay' 'Dependency'
#  'Deployment' 'Development' 'Device' 'Device Integration' 'Diagnosis'
#  'Diagnostics' 'Digital' 'Digital Campaign' 'Digital Initiatives'
#  'Digital Marketing' 'Digital Presence' 'Digital Strategy' 'Digital Tool'
#  'Digital Tools' 'Digital Transformation' 'Disappointment' 'Discount'
#  'Discounts' 'Disruption' 'Document' 'Documentation' 'Driver'
#  'E-signature' 'ERP' 'Effectiveness' 'Efficiency' 'Email Campaign'
#  'Email Marketing' 'Emergency' 'Employee' 'Encryption' 'Endpoint Security'
#  'Engagement' 'Enhancement' 'Error' 'Evaluation' 'Expansion' 'Expertise'
#  'Exploitation' 'Feature' 'Fee' 'Feedback' 'Fehler' 'Finance' 'Financial'
#  'Financial Institution' 'Financial Loss' 'Financial Optimization'
#  'Financial Organization' 'Financial Services' 'Financial Support'
#  'Firewall' 'Firmware' 'Fix' 'Free Trial' 'Functionality' 'GCP'
#  'Gaming PCs' 'Gateway' 'Gateway Issue' 'Goals' 'Growth' 'Guidance'
#  'Guide' 'Guidelines' 'HIPAA' 'HR' 'Halted' 'Hardware' 'Healthcare'
#  'Healthcare Data' 'Healthcare IT' 'Healthcare Security' 'Hospital'
#  'Hospital IT' 'Hospital System' 'IT' 'Implementation' 'Improvement'
#  'Inaccuracy' 'Incident' 'Incident Response' 'Inconsistency'
#  'Industry Standard' 'Industry Standards' 'Influencer' 'Influencers'
#  'Information' 'Information Management' 'Information Security'
#  'Infrastructure' 'Infrastructure Management' 'Innovation' 'Input Issue'
#  'Inquiry' 'Insight' 'Insights' 'Installation' 'Integration'
#  'Integration Problem' 'Integrity' 'Interference' 'Internal Review'
#  'Intrusion' 'Investigation' 'Investment' 'Investment Analysis'
#  'Investment Optimization' 'Investment Strategy' 'Invoice'
#  'Invoice Generation' 'Issue' 'Issue Resolution' 'Keras' 'Kernel'
#  'Knowledge Base' 'Kubernetes' 'Large Dataset' 'Lead' 'Limitation' 'Linux'
#  'Load' 'Load Balancing' 'Log' 'Log Analysis' 'Login' 'Long-term'
#  'Loyalty' 'Machine Learning' 'Maintenance' 'Malfunction' 'Management'
#  'Market' 'Market Expansion' 'Market Growth' 'Market Trend'
#  'Market Trends' 'Marketing' 'Marketing Agency' 'Media Platforms'
#  'Medical' 'Medical Data' 'Medical Documentation' 'Medical Records'
#  'Medical Systems' 'Memory' 'Memory Leak' 'Messaging' 'Microservice'
#  'Microservices' 'Microsoft' 'Microsoft Dynamics' 'Misalignment'
#  'Mitigation' 'Model' 'Modeling' 'Monitoring' 'Network' 'Network Security'
#  'Networking' 'Neustart' 'Notification' 'Online Advertising'
#  'Online Engagement' 'Online Interaction' 'Online Marketing'
#  'Online Payment' 'Online Presence' 'Online Visibility' 'Operational'
#  'Optimization' 'Organization' 'Outage' 'Outcome' 'Outdated'
#  'Outdated Security' 'Outdated Software' 'Outlook Account' 'Outreach'
#  'Partitioning' 'Password' 'Password Reset' 'Patch' 'Patient Care'
#  'Patient Confidentiality' 'Patient Data' 'Patient Information'
#  'Patient Safety' 'PatientData' 'Payment' 'Payment Gateway'
#  'Payment Methods' 'Payment Options' 'Performance' 'Phishing' 'Plan'
#  'Planning' 'Platform' 'PlatformUpdate' 'Platforms' 'Plattform' 'Plugin'
#  'Policy' 'Portfolio' 'Potential Consequence' 'Pre-sale' 'Prediction'
#  'Predictive' 'Prevention' 'Pricing' 'Privacy' 'Problem' 'Problem-solving'
#  'Process' 'Procurement' 'Product' 'Product Integration'
#  'Product Promotion' 'Productivity' 'Project' 'Project Management'
#  'Project Planning' 'Promotion' 'Promotional' 'Prompt Response'
#  'Protection' 'Protocol' 'Purchase' 'PyTorch' 'Query' 'RapidMiner'
#  'Re-training' 'Real-Time' 'Real-time' 'Real-time Data' 'Reassessment'
#  'Reboot' 'Rebooting' 'Recommendation' 'Recommendations' 'Reconciliation'
#  'Recovery' 'Refund' 'Regulation' 'Regulations' 'Reinstallation'
#  'Reliability' 'Report' 'Report Generation' 'Reprocessing' 'Reputational'
#  'Research' 'Resolution' 'Resource' 'Resources' 'Response' 'Restart'
#  'Results' 'Revenue' 'Review' 'Risk' 'Risk Assessment' 'Risk Exposure'
#  'Risk Management' 'Root Cause' 'SAP' 'SAP ERP' 'SEO' 'SOC' 'SaaS'
#  'Safety' 'Safety Measures' 'Sales' 'Scalability' 'Screen Sharing'
#  'Search Engine' 'Security' 'Security Best Practices' 'Security Breach'
#  'Security Enhancement' 'Security Incident' 'Security Measures'
#  'Security Policy' 'Security Practice' 'Security Solutions'
#  'Security Update' 'Segmentation' 'Sensitive' 'Sensitive Data'
#  'Sensitive Information' 'SensitiveData' 'Sensitivity' 'Server'
#  'Server Synchronization' 'Service' 'Service Connection'
#  'Service Disruption' 'Service Improvement' 'Service Issue'
#  'Service Options' 'Service Packages' 'Service Restart' 'Setup'
#  'Skill Development' 'Social Media' 'Software' 'Software Bug'
#  'Software Compatibility' 'Software Conflict' 'Software Integration'
#  'Software Issue' 'Software Tools' 'Software Update' 'Software Upgrade'
#  'Software malfunction' 'SoftwareError' 'SoftwareUpdate' 'Specification'
#  'Speed' 'Stability' 'Standard' 'Strategy' 'Subversion' 'Support'
#  'Support Request' 'Suspicious Activity' 'Switch' 'Synchronisation'
#  'Synchronization' 'Synchronization Error' 'System' 'System Alert'
#  'System Analysis' 'System Breach' 'System Cache' 'System Capacity'
#  'System Check' 'System Compatibility' 'System Conflict' 'System Error'
#  'System Instability' 'System Integration' 'System Integrity'
#  'System Issue' 'System Overload' 'System Protection' 'System Reboot'
#  'System Requirements' 'System Restart' 'System Scan' 'System Security'
#  'System Slowdown' 'System Software Update' 'System Stability'
#  'System Synchronization' 'System Update' 'System Upgrade'
#  'System Vulnerability' 'System restart' 'System stability'
#  'SystemSecurity' 'Tactics' 'Target' 'Target Audience' 'Targeting' 'Team'
#  'Tech Support' 'Technical' 'Technical Assistance'
#  'Technical Specification' 'Technical Support' 'Technique' 'Technology'
#  'Technology Support' 'Telehealth' 'Telemedicine' 'Testing' 'Third-party'
#  'Threat' 'Threat Detection' 'Threat Prevention' 'Threat Protection'
#  'Tips' 'Tool' 'Tools' 'Toolset' 'Traffic' 'Training' 'Transaction'
#  'Transaction Log' 'Trend' 'Trends' 'Trial' 'Troubleshooting' 'Tutorial'
#  'Ubuntu' 'Unauthorized Access' 'Unresolved' 'Update' 'Upgrade' 'Urgency'
#  'Urgent' 'Urgent Action' 'Usage' 'User' 'User Experience' 'User Guidance'
#  'User Impact' 'Validation' 'Vendor Support' 'Virus' 'Visibility'
#  'Visual Design' 'Visualization' 'Visuals' 'Vulnerability' 'Webhook'
#  'Website' 'Workaround' 'Workflow' nan]
#
# There were 428 unique values in tag_7: ['API' 'Access' 'Access Control' 'Access Management' 'Account' 'Ad Spend'
#  'Adjustment' 'Advanced Tools' 'Advertising' 'Advice' 'Agency' 'Alarm'
#  'Alert' 'Analysis' 'Analysis Method' 'Analytics' 'App' 'Application'
#  'Application Issue' 'Assistance' 'Audience' 'Audience Mismatch'
#  'Audience Segmentation' 'Audio Editing' 'Audit' 'Automation'
#  'Availability' 'Awareness' 'Backend' 'Behavior' 'Benefits'
#  'Best Practice' 'Best Practices' 'Billing' 'Brand' 'Brand Awareness'
#  'Brand Development' 'Brand Expansion' 'Brand Growth' 'Brand Visibility'
#  'Branding' 'Breach' 'Browser' 'Browser Cache' 'Budget' 'Bug' 'Business'
#  'Business Development' 'Business Expansion' 'Business Growth'
#  'Business Objectives' 'Cache' 'Calibration' 'Campaign' 'Campaigns'
#  'Capacity' 'Case Study' 'Certification' 'Challenge' 'Challenges' 'Code'
#  'Collaboration' 'Community' 'Compatibility' 'Competition'
#  'Competitive Edge' 'Compliance' 'Confidential Data' 'Confidentiality'
#  'Configuration' 'Conflict' 'Connection' 'Connectivity' 'Consultation'
#  'Container' 'Content' 'Content Creation' 'Content Marketing'
#  'Content Variation' 'Conversion' 'Correction' 'Corrective Action' 'Cost'
#  'Cost Breakdown' 'Cost Estimation' 'Creative' 'Critical'
#  'Customer Engagement' 'Customer Loyalty' 'Customer Service'
#  'Customer Support' 'Customization' 'Dashboard' 'Data' 'Data Access'
#  'Data Accuracy' 'Data Analysis' 'Data Availability' 'Data Backup'
#  'Data Breach' 'Data Damage' 'Data Integration' 'Data Integrity'
#  'Data Issue' 'Data Management' 'Data Pipeline' 'Data Processing'
#  'Data Protection' 'Data Security' 'Data Synchronization' 'Database'
#  'Decision' 'Decision Making' 'Decision Support' 'Decision-Making'
#  'Decision-making' 'Delay' 'Deployment' 'Development' 'Device' 'Diagnosis'
#  'Diagnostic' 'Digital' 'Digital Campaign' 'Digital Growth'
#  'Digital Marketing' 'Digital Platforms' 'Digital Presence'
#  'Digital Strategy' 'Digital Tool' 'Digital Transformation'
#  'Disappointment' 'Discount' 'Discrepancy' 'Discussion' 'Disruption'
#  'Docker' 'Documentation' 'Effectiveness' 'Efficiency' 'Email Marketing'
#  'Employee' 'Encryption' 'Endpoint' 'Engagement' 'Enhancement'
#  'Enterprise' 'Error' 'Escalation' 'Expansion' 'Expense' 'External Attack'
#  'Failure' 'Feature' 'Feedback' 'Fees' 'Fehlerbehebung' 'Finance'
#  'Financial Data' 'Financial Goals' 'Financial Institution'
#  'Financial Strategy' 'Fine Tuning' 'Firewall' 'Firewall Assessment' 'Fix'
#  'Free Trial' 'Frequency' 'Functionality' 'Funktionalität' 'Gateway'
#  'Good Practice' 'Growth' 'Guidance' 'Hardware' 'Healthcare'
#  'Healthcare Data' 'Healthcare System' 'Healthcare Technology'
#  'Hospital Management' 'Hospital Solution' 'Hospital System'
#  'Hospital Systems' 'IT' 'Immediate Action' 'Impact' 'Implementation'
#  'Improvement' 'Incident' 'Inconsistency' 'Indexing' 'Influencer'
#  'Information' 'Information Security' 'Infrastructure' 'Innovation'
#  'Inquiry' 'Insight' 'Insights' 'Installation' 'Instruction' 'Integration'
#  'Integrity' 'Investigation' 'Investment' 'Investment Decision'
#  'Investment Strategy' 'Invoice' 'Invoicing' 'IoT' 'Issue'
#  'Issue Resolution' 'IssueResolution' 'Kubernetes' 'Kunde' 'Large Dataset'
#  'Lead' 'License' 'Load' 'Log' 'Long-term Commitment' 'Low Priority'
#  'Maintenance' 'Management' 'Manual' 'Market' 'Market Expansion'
#  'Market Trends' 'Marketing' 'Marketing Agency' 'Marketing Challenges'
#  'Media' 'Medical Data' 'Medical Information' 'MedicalData' 'Messaging'
#  'Microservice' 'Microservices' 'Misconfiguration' 'Mobile' 'Model'
#  'Modeling' 'Modern Technology' 'Monitoring' 'Network' 'Notification'
#  'Offer' 'Online' 'Online Advertising' 'Online Marketing'
#  'Online Presence' 'Online Visibility' 'Operation' 'Optimization'
#  'Organization' 'Organizational Development' 'Organizational Requirements'
#  'Outage' 'Outcome' 'Outdated Security' 'Outdated Software' 'Overload'
#  'Overview' 'Partnerships' 'Password Reset' 'Patch' 'Patient'
#  'Patient Data' 'Patient Information' 'Patient Safety' 'PatientPrivacy'
#  'Pattern' 'Payment' 'Payment Plan' 'Payment Plans' 'Payment System'
#  'Performance' 'Plan' 'Planning' 'Plans' 'Platform'
#  'Platform Compatibility' 'Platform Insight' 'Portfolio Optimization'
#  'Predictive' 'Prevention' 'Price' 'Pricing' 'Pricing Information'
#  'Privacy' 'Problem-Solving' 'Process' 'Process Challenge'
#  'Process Improvement' 'Product' 'Productivity' 'Productivity Tools'
#  'Progress' 'Project Management' 'Promotion' 'Protocol' 'Protocols'
#  'Purchase' 'Quality' 'Rapid Resolution' 'Real-Time Insight'
#  'Real-time Analytics' 'Reboot' 'Recommendation' 'Recommendations'
#  'Recovery' 'Refinement' 'Refund' 'Regulation' 'Relationship' 'Report'
#  'Reporting' 'Resolution' 'Resource' 'Resource Bottleneck'
#  'Resource Management' 'Resources' 'Response' 'Response Time' 'Restart'
#  'Revenue' 'Review' 'Risk' 'Risk Assessment' 'Risk Management'
#  'Root Cause' 'SAP ERP' 'SEO' 'SaaS' 'Safety' 'Safety Measure' 'Sales'
#  'Satisfaction' 'Scalability' 'Scan' 'Security' 'Security Features'
#  'Security Measures' 'Security Protocol' 'Security Vulnerability'
#  'SecurityAudit' 'Segmentation' 'Sensitive Data' 'Sensitive Information'
#  'Sensitive Resource' 'Server' 'Service' 'Service Inquiry' 'Service Issue'
#  'Service Log' 'Service Plan' 'Service Request' 'Service Restart' 'Setup'
#  'Setup Fee' 'Shopware' 'Sluggishness' 'Smartsheet' 'Social Media'
#  'Software' 'Software Update' 'Software Version' 'Solution' 'Solutions'
#  'Stability' 'Standards' 'Status Update' 'Strategy' 'Subscription'
#  'Support' 'Support Available' 'Support Inquiry' 'Synchronization'
#  'System' 'System Compatibility' 'System Error' 'System Inconsistency'
#  'System Integration' 'System Integrity' 'System Investigation'
#  'System Issue' 'System Protection' 'System Restart' 'System Security'
#  'Tactics' 'Target Audience' 'Tariff Plan' 'Tech Support'
#  'Technical Issue' 'Technical Support' 'TechnicalSupport' 'Technology'
#  'Telemedicine' 'Threat Prevention' 'ThreatPrevention' 'Tool'
#  'Tool Support' 'Tools' 'Traffic' 'Training' 'Transaction' 'Trend' 'Trial'
#  'Troubleshooting' 'Unauthorized Access' 'Understanding' 'Update'
#  'Upgrade' 'Urgency' 'Urgent' 'User Experience' 'User Guide' 'Version'
#  'Visibility' 'Vulnerability' 'Website' 'Website Traffic' 'Whitepaper'
#  'Wi-Fi Security' 'Workaround' 'Workflow' 'Zapier' nan]
#
# There were 225 unique values in tag_8: ['Access Control' 'Access Restriction' 'Account' 'Adjustment'
#  'Advertising' 'Advice' 'Agency' 'Alert' 'Algorithm' 'Analytics'
#  'Application' 'Assessment' 'Assistance' 'Audience' 'Audit' 'Availability'
#  'Backup' 'Best Practice' 'Best Practices' 'Billing' 'Billing Period'
#  'Brand' 'Brand Awareness' 'Brand Development' 'Brand Growth'
#  'Brand Visibility' 'Branding' 'Bug' 'Business' 'Business Development'
#  'Business Expansion' 'Business Growth' 'Cache' 'Cache Clear' 'Caching'
#  'Campaign' 'Case Study' 'Communication' 'Compatibility' 'Compliance'
#  'Confidentiality' 'Configuration' 'Connection' 'Consultation' 'Content'
#  'Cost Analysis' 'Credential' 'Credit Card' 'Customer' 'Customer Inquiry'
#  'Customer Journey' 'Customer Service' 'Customer Support' 'Customization'
#  'Dashboard' 'Data' 'Data Analytics' 'Data Availability' 'Data Encryption'
#  'Data Format' 'Data Overload' 'Data Synchronization' 'Database'
#  'Decision' 'Decision Making' 'Delay' 'Digital' 'Digital Integration'
#  'Digital Marketing' 'Digital Tools' 'Discount' 'Discrepancy' 'Disruption'
#  'Documentation' 'Downgrade' 'EMR' 'Effectiveness' 'Efficiency' 'Effort'
#  'Email' 'Engagement' 'Error' 'Error Fix' 'Error Resolution' 'Feature'
#  'Features' 'Feedback' 'Fees' 'Financial' 'Financial Issue'
#  'Financial Organization' 'Firmware' 'Functionality' 'Growth' 'Guidance'
#  'Hardware' 'Healthcare' 'High Return' 'Hospital' 'IT' 'Implementation'
#  'Improvement' 'Incident' 'Influencer Partnerships' 'Information'
#  'Information Security' 'Infrastructure' 'Ink' 'Insight' 'Insights'
#  'Integration' 'Integration Error' 'Integrity' 'Investigation' 'Issue'
#  'Issue Analysis' 'Long-term Commitment' 'Maintenance' 'Marketing'
#  'Marketing Activity' 'Medical Data' 'MedicalInformation' 'MySQL'
#  'Network' 'Ongoing Charge' 'Online Advertising' 'Online Initiative'
#  'Online Presence' 'Operation' 'Opportunity' 'Optimization' 'Organization'
#  'Patient Data' 'Patient Privacy' 'Patient Safety' 'Payment Methods'
#  'Performance' 'Platform' 'Platform Integration' 'Prediction'
#  'Predictive Analytics' 'Pricing' 'Privacy' 'Problem' 'Process' 'Product'
#  'Product Advice' 'Product Portfolio' 'Progress' 'Project Management'
#  'Promotion' 'Protection' 'Protocol' 'Recommendation' 'Recovery'
#  'Regulations' 'Reinforcement' 'Reporting' 'Research' 'Resolution'
#  'Resource' 'Resources' 'Response' 'Revenue' 'Review' 'Robustness'
#  'Root Cause' 'SaaS' 'Scalability' 'Search Engine' 'Security'
#  'Security Solutions' 'Security Update' 'Sensitive' 'Sensitive Data'
#  'Service' 'Service Breakdown' 'Setup' 'Social Media' 'Software'
#  'Software Update' 'Solution' 'Spotify' 'Standards' 'Strategy' 'Success'
#  'Success Story' 'Support' 'System' 'System Availability' 'System Problem'
#  'System Security' 'SystemSlowdown' 'Tactics' 'Team Collaboration'
#  'Team Management' 'Tech Support' 'Technical Support' 'Technical Tools'
#  'Technique' 'Techniques' 'Technology' 'Technology Sector' 'Tier'
#  'Timeline' 'Timely' 'Tool' 'Tool Support' 'Training' 'Trend' 'Trial'
#  'Troubleshooting' 'Tutorial' 'Update' 'Urgent' 'User Experience'
#  'User Troubleshooting' 'VR Headset' 'Verification' 'Visibility'
#  'Vulnerability' 'Website' 'Wi-Fi' 'Workflow' nan]
